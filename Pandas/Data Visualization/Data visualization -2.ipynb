# %% [markdown]
# ### Legend

# %%
import matplotlib.pyplot as plt
import numpy as np

x=[1,2,3,4]
y=[2,5,6,7]
z=[1,2,3,4]
plt.plot(x,y,':k')
plt.plot(x,z,)
plt.legend([2,1],loc='lower right', ncol=2,facecolor='yellow',edgecolor='black',fontsize=10,shadow=True,labelcolor='red' , numpoints=4)

plt.show()

# %% [markdown]
# #### matplotlib.axes.Axes.legend() Function

# %%
# Implementation of matplotlib function 
import numpy as np 
import matplotlib.pyplot as plt 

np.random.seed(19680801) 

fig, ax = plt.subplots() 
for color in [ 'tab:green', 'tab:blue', 
			'tab:orange']: 
	n = 70
	x, y = np.random.rand(2, n) 
	scale = 1000.0 * np.random.rand(n) 
	ax.scatter(x, y, c = color, s = scale, 
			label = color, 
			alpha = 0.8) 

ax.legend(loc='best') 
ax.grid(False) 
fig.suptitle('matplotlib.axes.Axes.legend() function', fontweight ="bold") 

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (8 , 5))

plt.plot([1, 2, 4, 8, 30, 1])
plt.plot([1, 6, 13, 20, 38, 1])
plt.plot([1, 4, 8, 14, 20, 1])
plt.plot([1, 3, 4, 5, 10, 1])

#Using prop keyword in legend to change font size
plt.legend(['blue', 'orange', 'green', 'red'], 
#         prop={'size':10},
		loc = 'upper left', shadow = True,
		facecolor = 'yellow' ,fontsize=13,labelspacing=2,ncols=2)
plt.show()

# %%
# Importing required libraries 
import matplotlib.pyplot as plt 
import numpy as np 

# 2 subplots in 1 row and 2 columns 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5)) 

x1 = ['Telugu', 'Hindi', 'English', 
	'Maths', 'Science', 'Social'] 
y1 = [45, 34, 30, 45, 50, 38] 
y2 = [36, 28, 30, 45, 38, 48] 

# Labels to use in the legend for each line 
labels = ["in 2019", "in 2020"] 

# Title for subplots 
fig.suptitle('Number of Students passed in each subject\from a class in 2019 & 2020', fontsize=20) 

# Creating the sub-plots. 
l1 = ax1.plot(x1, y1, color="green") 
l2 = ax2.plot(x1, y2, color="blue") 

ax1.set_yticks(np.arange(0, 51, 5)) 
ax2.set_yticks(np.arange(0, 51, 5)) 

ax1.set_ylabel('Number of students', fontsize=25) 


fig.legend([l1, l2], labels=labels, 
		loc="upper right") 

# Adjusting the sub-plots 
plt.subplots_adjust(right=0.9) 

plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_3156\3950714305.py:29: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend([l1, l2], labels=labels,
# C:\Users\akash\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Plotting sub-plots of number of  
# students passed in each subject  
# in academic year 2017-20. 
import matplotlib.pyplot as plt 
import numpy as np 
  
plt.style.use('seaborn')  # Plot Styles 
  
fig = plt.figure() 
  
# 4 subplots in 2 rows and 2 columns in a figure 
axes = fig.subplots(nrows=2, ncols=2) 
  
axes[0, 0].bar(['Telugu', 'Hindi', 'English',  
                'Maths', 'Science', 'Social'], 
               [50, 27, 42, 34, 45, 48],  
               color='g', label="Students passed in 2017") 
  
axes[0, 0].set_yticks(np.arange(0, 51, 5)) 
  
axes[0, 1].bar(['Telugu', 'Hindi', 'English',  
                'Maths', 'Science', 'Social'], 
               [50, 27, 42, 34, 45, 48],  
               color='y', label="Students passed in 2018") 
  
axes[0, 1].set_yticks(np.arange(0, 51, 5)) 

plt.xticks(rotation=45) 
  
axes[1, 0].bar(['Telugu', 'Hindi', 'English',  
                'Maths', 'Science', 'Social'], 
               [40, 27, 22, 44, 35, 38], 
               color='r', label="Students passed in 2019") 
  
axes[1, 0].set_yticks(np.arange(0, 51, 5)) 
axes[1, 0].set_xlabel('Subjects', fontsize=25) 

 
axes[1, 0].set_ylabel(" Number of Students passed in 2017-2020", fontsize=20) 
  
  
axes[1, 1].bar(['Telugu', 'Hindi', 'English', 
                'Maths', 'Science', 'Social'], 
               [40, 27, 32, 44, 45, 48],  
               color='b', label="Students passed in 2020") 

for tick in axes[1, 0].get_xticklabels(): 
    tick.set_rotation(45) 
  
axes[1, 1].set_xlabel('Subjects', fontsize=20) 
axes[1, 1].set_yticks(np.arange(0, 51, 5)) 
lines = [] 
labels = [] 
  
for ax in fig.axes: 
    Line, Label = ax.get_legend_handles_labels() 
    # print(Label) 
    lines.extend(Line) 
    labels.extend(Label) 

plt.xticks(rotation=45) 
  
fig.legend(lines, labels, loc='upper right') 

plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_3156\1321725059.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')  # Plot Styles

# %%
# Import libraries 
import matplotlib.patches as mpatches 
import matplotlib.pyplot as plt 

# Creating plot 
plt.plot([1, 2, 3, 4], color='blue') 
plt.grid(False)

plt.title('simple legend example ') 

# Creating legend with color box 

blue_patch=mpatches.Patch(color='orange',label='blue line')
plt.legend(handles=[blue_patch]).remove()

# Show plot 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 100)
y1 = np.power(x, 2)
y2 = np.power(x, 3)

fig, axs = plt.subplots(2, 1)

axs[0].plot(x, y1, c = 'r',label = 'x^2')
axs[1].plot(x, y2, c = 'g',label = 'x^3')

axs[0].legend(loc = 'upper left').set_visible(False)
axs[1].legend(loc = 'upper left').remove()

axs[1].legend().remove()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

fig, ax = plt.subplots()

ax.plot(x, y1,c = 'r',label = 'Sine')
ax.plot(x, y2,c = 'g',label = 'Cosine')
leg = plt.legend()
ax.legend_ = None

plt.show()

# %%
# importing packages
import numpy as np
import matplotlib.pyplot as plt

# create data
x = np.linspace(1, 10, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

# plot graph
plt.plot(x, y1)
plt.plot(x, y2)

# add legend and remove frame
plt.legend(['Sine wave', 'Cos wave'],frameon=False)
plt.show()

# %% [markdown]
# #### Creating Different Types of Plots
#
# * **Line Graph**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[2,5,6,7,7,8,9]
y=[46,8,0,3,2,2,1]

x1 = np.array([1, 2, 3, 4,6,7]) 
y1 = x1*2
plt.plot(x,y)
plt.plot(x1,y1,':k')
plt.title('line graph')
plt.fill_between()
plt.show()

# %%
x=[2,5,6,7,7,8,9]
y=[46,8,0,3,2,2,1]

# x1 = np.array([1, 2, 3, 4,6,7]) 
y1 = [i*2 for i in x]
plt.plot(x,y)
plt.plot(x,y1,':k')
plt.title('line graph')
plt.fill_between(x,y,y1)
plt.show()

# %%
import random
students = ["Jane","Joe","Beck","Tom","Sam", 
            "Eva","Samuel","Jack","Dana","Ester", 
            "Carla","Steve","Fallon","Liam","Culhane", 
            "Candance","Ana","Mari","Steffi","Adam"] 
  
marks=[] 
for i in range(0,len(students)): 
     marks.append(random.randint(0, 101)) 
  
  
plt.xlabel("Students") 
plt.xticks(rotation=40)
plt.ylabel("Marks") 
plt.title("CLASS RECORDS") 
plt.plot(students,marks,'o-g',markerfacecolor='r',markersize=10)

# %%
# draw horizontal or vertical lines

# %%
import matplotlib.pyplot as plt 
  
# plotting line within the given range 
plt.axhline(y = .5, xmin = 0.25, xmax = 0.9) 
plt.axhline(y=2,xmin=0,xmax=1.9)
plt.show()

# %%
plt.axvline(ymin=0,ymax=4,x=2)  # first method

# %%
plt.vlines(x=3,ymin=2,ymax=4)

# %%
plt.plot((0, 4), (0, 1), scaley = False)

# %%
plt.plot((0,0), (0, 1), scaley = False)

# %%
plt.plot((0,1), (0.2,0.2), scalex= False)

# %%
# importing package 
import matplotlib.pyplot as plt 

# create data 
x = [10,20,30,40,50] 
y = [30,30,30,30,30] 

# plot lines 
plt.plot(x, y, label = "line 1") 
plt.plot(y, x, label = "line 2",alpha=.3,linewidth=10) 
plt.legend() 
plt.show()

# %%
x=np.arange(0.1, 0.3, 0.1)
for i in np.arange(0.1,1,0.1):
    plt.plot([0.1,0.2,0.3], [i]*3,color='b', linewidth=10,alpha=i)
    plt.plot([0.4,0.5,0.6], [i]*3,color='r', linewidth=10,alpha=i)

# %%
x = np.arange(0.0, 2, 0.01)
y1 = np.sin(2 * np.pi * x)
y2 = 0.8 * np.sin(4 * np.pi * x)

fig,((ax1,ax2,ax3))=plt.subplots(nrows=3,ncols=1,figsize=(6,6),sharex=True)
ax1.fill_between(x,y1,color='r',edgecolor='k')
ax2.fill_between(x,y1,1,color='y',edgecolor='k')
ax3.fill_between(x,y1,y2,color='c',edgecolor='k')
fig.tight_layout()

# %% [markdown]
# #### BAR PLOT

# %%
import matplotlib.pyplot as plt 
# data to display on plots 
x = [3, 1, 3, 12, 2, 4, 4]  
y = [3, 2, 1, 4, 5, 6, 7]

# This will plot a simple bar chart 
plt.bar(x,y) 

# Title to the plot 
plt.title("Bar Chart") 

# Adding the legends 
plt.legend(["bar"]) 
plt.show()

# %%
data = {'C':20, 'C++':15, 'Java':30, 
        'Python':35}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (5,3))

plt.bar(courses,values,color='maroon',edgecolor='k',width=0.1)
fig.tight_layout()

# %%
plt.barh(courses,values,color='maroon',edgecolor='k',height=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
x = ['A', 'B', 'C', 'D']
y1 = [10, 20, 10, 30]
y2 = [20, 25, 15, 25]

plt.bar(x,y1,color='b',edgecolor='y')
plt.bar(x,y2, bottom=y1,color='r',edgecolor='k')
# Out:
# <BarContainer object of 4 artists>

# %%
x = ['A', 'B', 'C', 'D']
y1 = np.array([10, 20, 10, 30])
y2 = np.array([20, 25, 15, 25])
y3 = np.array([12, 15, 19, 6])
y4 = np.array([10, 29, 13, 19])

plt.bar(x,y1,color='g',label='Round1')
plt.bar(x,y2,bottom=y1, color='k' ,label='Round2')
plt.bar(x,y3,bottom=y1+y2,color='maroon', label='Round3')
plt.bar(x,y4,bottom=y1+y2+y3,color='y', label='Round4')
plt.legend(ncol=2 ,frameon=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# create data
df = pd.DataFrame([['A', 10, 20, 10, 26], ['B', 20, 25, 15, 21], ['C', 12, 15, 19, 6],
                   ['D', 10, 18, 11, 19]],
                  columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4'])
# view data
print(df)
# Out:
#   Team  Round 1  Round 2  Round 3  Round 4
# 0    A       10       20       10       26
# 1    B       20       25       15       21
# 2    C       12       15       19        6
# 3    D       10       18       11       19

# %%
df.plot(x='Team',kind='bar',stacked=True,title='stacked bar graph',mark_right=True,hatch='/')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'A'), Text(1, 0, 'B'), Text(2, 0, 'C'), Text(3, 0, 'D')])

# %%
import matplotlib.pyplot as plt
import numpy as np

data ={
    'Category A':[20, 30, 50],
    'Category B':[10, 40, 50],
    'Category C':[30, 10, 60]
}

df = pd.DataFrame(data, index=['Subgroup 1', 'Subgroup 2', 'Subgroup 3'])

df_array = df.to_numpy()

# Normalize the data to percentages
df_percentage = (df_array / df_array.sum(axis=1)[:, None]) * 100

fig, ax = plt.subplots()
bottom = np.zeros(len(df.columns))

for i, column in enumerate(df.columns):
    bars = ax.bar(df.index, df_percentage[:, i], label=column, bottom=bottom, alpha=0.7)
    for bar, percentage in zip(bars,df_percentage[:, i]):
        height=bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, bottom[i] + height / 2,
                f'{percentage:.1f}%', ha='center', va='center', color='Black', fontsize=12)
    bottom += df_percentage[:, i]

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt

# create data
A = np.array([3,6,9,4,2,5])
B = np.array([2,8,1,9,7,3])
X = np.arange(6)
print(X)
# plot the bars
plt.barh(X, A, color = 'r', )
plt.barh(X, -B, color = 'b')
plt.title("Back-to-Back Bar Chart")
plt.show()
# Out:
# [0 1 2 3 4 5]

# %%
A = np.array([3,6,9,4,2,5])
B = np.array([-2,-8,-1,-9,-7,-3])
x=np.arange(6)
plt.barh(x,A,edgecolor='k')
plt.barh(x,B,edgecolor='k')
plt.grid(alpha=.3)

# %%
x = [0, 1, 2, 3, 4, 5, 6, 7]
y = [160, 167, 17, 130, 120, 40, 105, 70]


fig,ax=plt.subplots()
z=np.arange(len(y))
ax.barh(z,y,0.75,color='g')

for i,v in enumerate(y):
    ax.text(v+1,i+0.25,str(v),fontsize=12,color='maroon')

# %%
x = [0, 1, 2, 3, 4, 5, 6, 7]
y = [160, 167, 17, 130, 120, 40, 105, 70]


fig,ax=plt.subplots()
ax.bar(x,y,color='g')

for i,v in enumerate(y):
    ax.text(i,v,str(v),fontsize=12,color='maroon' )

# %%
x = ["A", "B", "C", "D"]
y = [1, 2, 3, 4]
plt.barh(x,y)

for index,value in enumerate(y):
    plt.text(value/2,index,str(value))

# %%
print(2+3/2)
# Out:
# 3.5

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Creating our own dataframe
data = {"Name": ["Alex", "Bob", "Clarein", "Dexter"],
		"Marks": [45, 23, 78, 65]}


df = pd.DataFrame(data, columns=['Name', 'Marks'])
df
# Out:
#       Name  Marks
# 0     Alex     45
# 1      Bob     23
# 2  Clarein     78
# 3   Dexter     65

# %%
plt.figure(figsize=(8,7))
plots=sns.barplot(x='Name',y='Marks',data=df)
plt.xlabel('Names',size=10)
plt.ylabel('Secured marks',size=10)

for bar in plots.patches:
#     plots.annotate(format(bar.get_height(), '.2f'), 
#                    (bar.get_x() + bar.get_width() / 2, 
#                     bar.get_height()), ha='center', va='center',
#                    size=15, xytext=(0, 8),
#                    textcoords='offset points')
    plots.annotate((format(bar.get_height(),'.0f'))+'%',
                   (bar.get_x()+bar.get_width()/2, bar.get_height()),
                   ha='center',
                   va='center',
                   size=15,
                   xytext=(0,8),
                   textcoords='offset pixels')

# %%
x=['Akash','Anup','Basu','Nirmala','Anu','Poo']
y=[0,67,78,90,78,88]

data={'Names':x,
     'Marks':y}
df=pd.DataFrame(data)
df

plt.figure(figsize=(8,6))
plots=sns.barplot(x='Names',y='Marks',data=df)

for bar in plots.patches:
    plots.annotate((format(bar.get_height(), '.0f')+'%') ,
                  (bar.get_x() + bar.get_width() / 2, bar.get_height()/2),
                  xytext=(0,8),
                  ha='center',
                  va='center',
                  size=15,
                  textcoords='offset points')

# %%
x=['Akash','Anup','Basu','Nirmala','Anu','Poo']
y=[0,67,78,90,78,88]

data={'Names':x,
     'Marks':y}
df=pd.DataFrame(data)
df

plt.figure(figsize=(8,6))
plots=sns.barplot(x='Names',y='Marks',data=df)

for bar in plots.patches:
    plots.annotate((format(bar.get_height(), '.0f')+'%') ,
                  (bar.get_x() + bar.get_width() / 2, bar.get_height()),
                  xytext=(0,8),
                  ha='center',
                  va='center',
                  size=15,
                  textcoords='offset points')

# %%
# code to plot a simple grouped barplot 
plt.figure(figsize=(8, 6)) 
sns.barplot(x="Names", y="Marks", data=df, ) 

plt.ylabel("Average Age", size=14) 
plt.xlabel("Ticket Class", size=14) 
plt.title("Simple Grouped Barplot", size=18)
# Out:
# Text(0.5, 1.0, 'Simple Grouped Barplot')

# %%
df=pd.read_csv("D:/Pandas/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_final=df.groupby(['Sex','Pclass']).agg(avg_age=('Age', 'mean'), count=('Sex', 'count')).reset_index()

# %%
df_final
# Out:
#       Sex  Pclass    avg_age  count
# 0  female       1  34.611765     94
# 1  female       2  28.722973     76
# 2  female       3  21.750000    144
# 3    male       1  41.281386    122
# 4    male       2  30.740707    108
# 5    male       3  26.507589    347

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
plots=sns.barplot(x='Pclass',y='avg_age',data=df_final,hue='Sex',palette='Greens')

for bar in plots.patches:
    plots.annotate((format(bar.get_height(),'.0f'))+' Years',
                  (bar.get_x()+bar.get_width()/2, bar.get_height()/2),
                  xytext=(0,6),
                   ha='center',
                   va='center',
                  textcoords='offset points')

# %%
import numpy as np 
import matplotlib.pyplot as plt 

# set width of bar 
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8)) 

# set height of bar 
IT = [12, 30, 1, 8, 22] 
ECE = [28, 6, 16, 5, 10] 
CSE = [29, 3, 24, 25, 17] 

# Set position of bar on X axis 
br1 = np.arange(len(IT)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 

br1,br2,br3
# # Make the plot
plt.bar(br1, IT, color ='r', width = barWidth, 
		edgecolor ='grey', label ='IT') 
plt.bar(br2, ECE, color ='g', width = barWidth, 
		edgecolor ='grey', label ='ECE') 
plt.bar(br3, CSE, color ='b', width = barWidth, 
		edgecolor ='grey', label ='CSE') 

# # Adding Xticks 
plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(len(IT))], 
		['2015', '2016', '2017', '2018', '2019'])

plt.legend()
plt.show()

# %%
import pandas as pd
data={
    'Names':['Akash','Anup','Basu','Nirmala','Xyz','abc'],
    'Marks':[45,35,67,89,90,55],
    'marks1':[23,45,6,8,9,34]
}


df=pd.DataFrame(data)
df.set_index('Names',inplace=True)
plt.figure(figsize=(8,6))
plots=df.plot(kind='barh',stacked=False)
plt.xticks(rotation=0)

# for bar in plots.patches:
#     plots.annotate((format(bar.get_height(),'.0f')),
#                   (bar.get_x()+bar.get_width()/2,bar.get_height()/2),
#                   xytext=(0,6),
#                    ha='center',
#                    va='center',
#                   textcoords='offset points')

for i,v in enumerate(df['Marks']):
    plt.text(v/2,i-0.20,str(v)+'%')
for i,v in enumerate(df['marks1']):
    plt.text(v/2,i+0.05,str(v)+'%')

# %%
x=np.arange(6)
y1=[1,2,3,4,5,6]
y2=[-6,-5,-4,-3,-2,-1]

plt.barh(x,y1)
plt.barh(x,y2)
# Out:
# <BarContainer object of 6 artists>

# %%
data={
    'program':['python','java','c','c++'],
    'Demand in %':[89,45,67,89]
}
df= pd.DataFrame(data)
df.set_index('program',inplace=True)

fig,ax= plt.subplots(figsize=(8,6))
ax.bar(x=df.index,height='Demand in %',data=df,align='center',color=['pink','m','y','b'])
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

for i,v in enumerate(df['Demand in %']):
    ax.text(i,v+2,str(v)+'%',ha='center',va='center',fontsize=13)

# %%
# bar chart stacked hori and verti

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



data = pd.read_csv("D:/Pandas/netflix_titles.csv")

data = data.loc[data['release_year'].isin([*range(2016, 2020)]), ['type', 'release_year']].copy()
data.dropna(inplace=True)
data['release_year'] = data['release_year'].astype('int')
data
# Out:
#          type  release_year
# 21    TV Show          2018
# 37    TV Show          2018
# 38      Movie          2017
# 73      Movie          2018
# 87    TV Show          2019
# ...       ...           ...
# 8787    Movie          2017
# 8794    Movie          2016
# 8796  TV Show          2016
# 8797  TV Show          2016
# 8803  TV Show          2018
#
# [4111 rows x 2 columns]

# %%
cross_tab_prop = pd.crosstab(index=data['release_year'],
                             columns=data['type'],
                             normalize="index")
cross_tab_prop
# Out:
# type             Movie   TV Show
# release_year
# 2016          0.729490  0.270510
# 2017          0.743217  0.256783
# 2018          0.668701  0.331299
# 2019          0.614563  0.385437

# %%
cross_tab = pd.crosstab(index=data['release_year'],
                        columns=data['type'])
cross_tab
# Out:
# type          Movie  TV Show
# release_year
# 2016            658      244
# 2017            767      265
# 2018            767      380
# 2019            633      397

# %%
cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    colormap='tab10', 
                    figsize=(10, 6))

plt.legend(loc="upper left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")


for n, x in enumerate([*cross_tab.index.values]):
    for (proportion, count, y_loc) in zip(cross_tab_prop.loc[x],
                                          cross_tab.loc[x],
                                          cross_tab_prop.loc[x].cumsum()):
        
        plt.text(x=n-0.17,
                 y=(y_loc- proportion) + (proportion / 2),
                 s=f'{count}\n({np.round(proportion * 100, 1)}%)', 
                 color="black",
                 fontsize=12,
                 fontweight="bold")

plt.show()

# %%
cross_tab_prop.plot(kind='barh', 
                        stacked=True, 
                        colormap='tab10', 
                        figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.ylabel("Release Year")
plt.xlabel("Proportion")


for n, x in enumerate([*cross_tab.index.values]):
    for (proportion, count, y_loc) in zip(cross_tab_prop.loc[x],
                                          cross_tab.loc[x],
                                          cross_tab_prop.loc[x].cumsum()):
                
        plt.text(x=(y_loc - proportion) + (proportion / 2),
                 y=n - 0.11,
                 s=f'{count}\n({np.round(proportion * 100, 1)}%)', 
                 color="black",
                 fontsize=12,
                 fontweight="bold")

plt.show()

# %%
data={
    'Name':['Akash','Anup','Ak','pk','ck'],
    'studied':[2.3,4,4.5,5,6],
    'slept':[4,5,6,7,8],
    'other':[7,8,9,2,3]
}
df=pd.DataFrame(data)
df.set_index('Name',inplace=True)
df
# Out:
#        studied  slept  other
# Name
# Akash      2.3      4      7
# Anup       4.0      5      8
# Ak         4.5      6      9
# pk         5.0      7      2
# ck         6.0      8      3

# %%
df.plot(kind='bar', 
        stacked=True, 
        colormap='tab10', 
        figsize=(10, 6))

for n, x in enumerate([*df.index.values]):
    for (perct,y_loc) in zip(df.loc[x],df.loc[x].cumsum()):
        plt.text(x=n-0.17,
               y=(y_loc-perct)+perct/2,
               s=f'{perct*100}%',
               color='k',
               fontsize=12,
            fontweight="bold")

# %%
df.plot(kind='barh', 
        stacked=True, 
        colormap='tab10', 
        figsize=(10, 6))

for n, x in enumerate([*df.index.values]):
    for (perct,y_loc) in zip(df.loc[x],df.loc[x].cumsum()):
        plt.text(y=n-0.17,
               x=(y_loc-perct)+perct/2,
               s=f'{perct*100}%',
               color='k',
               fontsize=12,
            fontweight="bold")

plt.legend(bbox_to_anchor=[1,1],ncols=2,shadow=True, fontsize=12)
