# %% [markdown]
# ### Dataset
#
# https://www.kaggle.com/c/titanic/data?select=train.csv

# %%
import pandas as pd

data=pd.read_csv('train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %%
data.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  ...      Ticket   Fare  Cabin  Embarked
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"  ...  W./C. 6607  23.45    NaN         S
# 889          890         1       1                     Behr, Mr. Karl Howell  ...      111369  30.00   C148         C
# 890          891         0       3                       Dooley, Mr. Patrick  ...      370376   7.75    NaN         Q
#
# [3 rows x 12 columns]

# %%
print(f"number of rows in the dataset is : {data.shape[0]}")
print(f"number of columns in the dataset is : {data.shape[1]}")
# Out:
# number of rows in the dataset is : 891
# number of columns in the dataset is : 12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name  ...  Ticket        Fare    Cabin  Embarked
# count    891.000000  891.000000  891.000000                      891  ...     891  891.000000      204       889
# unique          NaN         NaN         NaN                      891  ...     681         NaN      147         3
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  ...  347082         NaN  B96 B98         S
# freq            NaN         NaN         NaN                        1  ...       7         NaN        4       644
# mean     446.000000    0.383838    2.308642                      NaN  ...     NaN   32.204208      NaN       NaN
# std      257.353842    0.486592    0.836071                      NaN  ...     NaN   49.693429      NaN       NaN
# min        1.000000    0.000000    1.000000                      NaN  ...     NaN    0.000000      NaN       NaN
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sum(data['Sex']=='male')
# Out:
# 577

# %%
data[data['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name  ...            Ticket     Fare  Cabin  Embarked
# 0              1         0       3         Braund, Mr. Owen Harris  ...         A/5 21171   7.2500    NaN         S
# 4              5         0       3        Allen, Mr. William Henry  ...            373450   8.0500    NaN         S
# 5              6         0       3                Moran, Mr. James  ...            330877   8.4583    NaN         Q
# 6              7         0       1         McCarthy, Mr. Timothy J  ...             17463  51.8625    E46         S
# 7              8         0       3  Palsson, Master. Gosta Leonard  ...            349909  21.0750    NaN         S
# ..           ...       ...     ...                             ...  ...               ...      ...    ...       ...
# 883          884         0       2   Banfield, Mr. Frederick James  ...  C.A./SOTON 34068  10.5000    NaN         S
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['Survived'].nunique()
# Out:
# 2

# %%
data[data['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 8              9         1       3  ...  11.1333   NaN         S
# 9             10         1       2  ...  30.0708   NaN         C
# ..           ...       ...     ...  ...      ...   ...       ...
# 875          876         1       3  ...   7.2250   NaN         C
# 879          880         1       1  ...  83.1583   C50         C
# 880          881         1       2  ...  26.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 889          890         1       1  ...  30.0000  C148         C
#
# [342 rows x 12 columns]

# %% [markdown]
# #### HANDLING NULL VALUES

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
perct_missing=data.isnull().sum()*100/len(data)

# %%
perct_missing
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
data.drop('Cabin',axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %% [markdown]
# #### HANDLLING MISSING VALUES

# %%
data['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
data['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
data['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
data['Age'].mean()
# Out:
# 29.69911764705882

# %%
data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# #### CATEGORICAL DATA ENCODING

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['Gender']=data['Sex'].map({'male':1,'female':0})

# %%
data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Embarked  Gender
# 0              1         0       3  ...   7.2500        S       1
# 1              2         1       1  ...  71.2833        C       0
# 2              3         1       3  ...   7.9250        S       0
# 3              4         1       1  ...  53.1000        S       0
# 4              5         0       3  ...   8.0500        S       1
# ..           ...       ...     ...  ...      ...      ...     ...
# 886          887         0       2  ...  13.0000        S       1
# 887          888         1       1  ...  30.0000        S       0
# 888          889         0       3  ...  23.4500        S       0
# 889          890         1       1  ...  30.0000        C       1
# 890          891         0       3  ...   7.7500        Q       1
#
# [891 rows x 12 columns]

# %%
x=data['Sex'].map({'male':1,'female':0})
data.insert(5,"Gender_New",x)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Embarked  Gender
# 0              1         0       3  ...   7.2500        S       1
# 1              2         1       1  ...  71.2833        C       0
# 2              3         1       3  ...   7.9250        S       0
# 3              4         1       1  ...  53.1000        S       0
# 4              5         0       3  ...   8.0500        S       1
# ..           ...       ...     ...  ...      ...      ...     ...
# 886          887         0       2  ...  13.0000        S       1
# 887          888         1       1  ...  30.0000        S       0
# 888          889         0       3  ...  23.4500        S       0
# 889          890         1       1  ...  30.0000        C       1
# 890          891         0       3  ...   7.7500        Q       1
#
# [891 rows x 13 columns]

# %%
pd.get_dummies(data,columns=['Embarked'])
# Out:
#      PassengerId  Survived  Pclass  ... Embarked_C Embarked_Q  Embarked_S
# 0              1         0       3  ...      False      False        True
# 1              2         1       1  ...       True      False       False
# 2              3         1       3  ...      False      False        True
# 3              4         1       1  ...      False      False        True
# 4              5         0       3  ...      False      False        True
# ..           ...       ...     ...  ...        ...        ...         ...
# 886          887         0       2  ...      False      False        True
# 887          888         1       1  ...      False      False        True
# 888          889         0       3  ...      False      False        True
# 889          890         1       1  ...       True      False       False
# 890          891         0       3  ...      False       True       False
#
# [891 rows x 15 columns]

# %%
data1=pd.get_dummies(data,columns=['Embarked'],drop_first=True)

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  ... Gender Embarked_Q  Embarked_S
# 0            1         0       3  ...      1      False        True
# 1            2         1       1  ...      0      False       False
# 2            3         1       3  ...      0      False        True
# 3            4         1       1  ...      0      False        True
# 4            5         0       3  ...      1      False        True
#
# [5 rows x 14 columns]

# %% [markdown]
# #### WHAT IS UNIVARIATE ANALYSIS ?

# %% [markdown]
# works on only one varible for analysis

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
# how many survived 
sum(data['Survived']==1)
# Out:
# 342

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# sns.countplot(data['Survived'])
data['Survived'].hist()
# Out:
# <Axes: >

# %%
# how many passagngers were in first class, second class and third classs

data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Pclass'].hist()
# Out:
# <Axes: >

# %%
sns.countplot(x='Pclass', data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# Number of male and female passanger count

data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
sns.countplot(x='Sex',data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.hist(data['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(data['Age'], orient='v')
# Out:
# <Axes: >

# %% [markdown]
# #### BIVARIATE ANALYSIS

# %% [markdown]
# Analysis on two Columns

# %%
# find out surviual rate for maleand female

sns.barplot(x='Sex',y='Survived',data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Gender', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.barplot(x='Pclass' , y='Survived', data=data) # which pssanger has beter chance of survuval (first ,second or third class)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# #### FEATURE ENIGNEERING

# %% [markdown]
# using domain knowledeg to extract features from raw data via data mining techniue using for ML

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
# finding size of family as column SibSp and Parch 

data['Family_size']=data['SibSp']+data['Parch']

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  ... Embarked Gender  Family_size
# 0            1         0       3  ...        S      1            1
# 1            2         1       1  ...        C      0            1
#
# [2 rows x 14 columns]

# %%
data['Fare_per_person']=data['Fare']/(data['Family_size']+1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  ... Gender Family_size  Fare_per_person
# 0              1         0       3  ...      1           1          3.62500
# 1              2         1       1  ...      0           1         35.64165
# 2              3         1       3  ...      0           0          7.92500
# 3              4         1       1  ...      0           1         26.55000
# 4              5         0       3  ...      1           0          8.05000
# ..           ...       ...     ...  ...    ...         ...              ...
# 886          887         0       2  ...      1           0         13.00000
# 887          888         1       1  ...      0           0         30.00000
# 888          889         0       3  ...      0           3          5.86250
# 889          890         1       1  ...      1           0         30.00000
# 890          891         0       3  ...      1           0          7.75000
#
# [891 rows x 15 columns]
