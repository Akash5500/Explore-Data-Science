# %% [markdown]
# ## Dataset
#
# https://www.kaggle.com/datasets/rahuldogra/top5000youtubechannels

# %%
import pandas as pd
import seaborn as sns
data=pd.read_csv('top-5000-youtube-channels.csv')
data
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0         1st  A++                       Zee TV         82757    18752951  20869786591
# 1         2nd  A++                     T-Series         12661    61196302  47548839843
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3         4th  A++                    SET India         27323    31180559  22675948293
# 4         5th  A++                          WWE         36756    32852346  26273668433
# ...       ...   ...                         ...           ...         ...          ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+                  Mastersaint           110     3265735    311758426
# 4998  4,999th   B+               Bruce McIntosh          3475       32990     14563764
# ...

# %%
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
data.head(-10) # dispaly all rows except last 10 rows
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0         1st  A++                       Zee TV         82757    18752951  20869786591
# 1         2nd  A++                     T-Series         12661    61196302  47548839843
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3         4th  A++                    SET India         27323    31180559  22675948293
# 4         5th  A++                          WWE         36756    32852346  26273668433
# ...       ...   ...                         ...           ...         ...          ...
# 4985  4,986th   B+            AndreaBocelliVEVO           191      820381    485771289
# 4986  4,987th   B+           CidadeAlertaRecord          7299     1123300    346376750
# 4987  4,988th   B+                YouANDi Games          1358     1536819    424688400
# 4988  4,989th   B+       GREAT IDEAS GREAT LIFE            80     1349511     46911690
# ...

# %%
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
data.tail(-5)  # dispaly all row except first 5 rows
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  Video views
# 5         6th  A++              Movieclips         30243    17149705  16618094724
# 6         7th  A++              netd müzik          8500    11373567  23898730764
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206  17202609850
# 8         9th  A++         Ryan ToysReview          1140    16082927  24518098041
# 9        10th  A++             Zee Marathi         74607     2841811   2591830307
# ...       ...   ...                    ...           ...         ...          ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+             Mastersaint           110     3265735    311758426
# 4998  4,999th   B+          Bruce McIntosh          3475       32990     14563764
# ...

# %%
data.shape
# Out:
# (5000, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
pd.options.display.float_format = '{:.2f}'.format
data.describe()
# Out:
#          Video views
# count        5000.00
# mean   1071449400.15
# std    2003843972.12
# min            75.00
# 25%     186232945.75
# 50%     482054780.00
# 75%    1124367826.75
# max   47548839843.00

# %% [markdown]
# ## data cleaning

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0    1st  A++                       Zee TV         82757    18752951  20869786591
# 1    2nd  A++                     T-Series         12661    61196302  47548839843
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3    4th  A++                    SET India         27323    31180559  22675948293
# 4    5th  A++                          WWE         36756    32852346  26273668433
# 5    6th  A++                   Movieclips         30243    17149705  16618094724
# 6    7th  A++                   netd müzik          8500    11373567  23898730764
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206  17202609850
# 8    9th  A++              Ryan ToysReview          1140    16082927  24518098041
# 9   10th  A++                  Zee Marathi         74607     2841811   2591830307
# ...

# %%
import numpy as np
data.replace(to_replace='--',value=np.nan,regex=True).head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0    1st  A++                       Zee TV         82757    18752951  20869786591
# 1    2nd  A++                     T-Series         12661    61196302  47548839843
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3    4th  A++                    SET India         27323    31180559  22675948293
# 4    5th  A++                          WWE         36756    32852346  26273668433
# 5    6th  A++                   Movieclips         30243    17149705  16618094724
# 6    7th  A++                   netd müzik          8500    11373567  23898730764
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206  17202609850
# 8    9th  A++              Ryan ToysReview          1140    16082927  24518098041
# 9   10th  A++                  Zee Marathi         74607     2841811   2591830307
# ...

# %%
#check null values in data set

# %%
data.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# data cleaning rank columns

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0  1st  A++                       Zee TV         82757    18752951  20869786591
# 1  2nd  A++                     T-Series         12661    61196302  47548839843
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3  4th  A++                    SET India         27323    31180559  22675948293
# 4  5th  A++                          WWE         36756    32852346  26273668433

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data['Rank']=data['Rank'].replace(to_replace=r'[^0-9]',value='',regex=True)

# %%
data
# Out:
#       Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0        1  A++                       Zee TV         82757    18752951  20869786591
# 1        2  A++                     T-Series         12661    61196302  47548839843
# 2        3  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3        4  A++                    SET India         27323    31180559  22675948293
# 4        5  A++                          WWE         36756    32852346  26273668433
# ...    ...   ...                         ...           ...         ...          ...
# 4995  4996   B+               Uras Benlioğlu           706     2072942    441202795
# 4996  4997   B+            HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4998   B+                  Mastersaint           110     3265735    311758426
# 4998  4999   B+               Bruce McIntosh          3475       32990     14563764
# ...

# %%
data['Rank'].astype(int)
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 4995    4996
# 4996    4997
# 4997    4998
# 4998    4999
# 4999    5000
# Name: Rank, Length: 5000, dtype: int32

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
# video upload and subscribers

# %%
data
# Out:
#       Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0        1  A++                       Zee TV         82757    18752951  20869786591
# 1        2  A++                     T-Series         12661    61196302  47548839843
# 2        3  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3        4  A++                    SET India         27323    31180559  22675948293
# 4        5  A++                          WWE         36756    32852346  26273668433
# ...    ...   ...                         ...           ...         ...          ...
# 4995  4996   B+               Uras Benlioğlu           706     2072942    441202795
# 4996  4997   B+            HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4998   B+                  Mastersaint           110     3265735    311758426
# 4998  4999   B+               Bruce McIntosh          3475       32990     14563764
# ...

# %%
data[['Video Uploads','Subscribers']].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 data[['Video Uploads','Subscribers']].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
data['Subscribers'].str.contains('--').sum()
# Out:
# 387

# %%
data['Subscribers'].replace('--', np.nan, regex=True,inplace=True)

# %%
data['Video Uploads'].str.contains('--').sum()
# Out:
# 6

# %%
data['Video Uploads'].replace('--', np.nan, regex=True,inplace=True)

# %%
data.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
data[['Video Uploads','Subscribers']]=data[['Video Uploads','Subscribers']].astype(int)

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads     int32
# Subscribers       int32
# Video views       int64
# dtype: object

# %%
## grade column

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
data['Grade']=data['Grade'].map({'A++ ':5, 'A+ ':4, 'A ': 3, 'A- ':2, 'B+ ':1})

# %%
data
# Out:
#       Rank  Grade                Channel name  Video Uploads  Subscribers  Video views
# 0        1      5                      Zee TV          82757     18752951  20869786591
# 1        2      5                    T-Series          12661     61196302  47548839843
# 2        3      5  Cocomelon - Nursery Rhymes            373     19238251   9793305082
# 3        4      5                   SET India          27323     31180559  22675948293
# 4        5      5                         WWE          36756     32852346  26273668433
# ...    ...    ...                         ...            ...          ...          ...
# 4995  4996      1              Uras Benlioğlu            706      2072942    441202795
# 4996  4997      1           HI-TECH MUSIC LTD            797      1055091    377331722
# 4997  4998      1                 Mastersaint            110      3265735    311758426
# 4998  4999      1              Bruce McIntosh           3475        32990     14563764
# ...

# %%
# average view for each channel

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data1=data.groupby('Channel name')['Video views'].mean()

# %%
data['Average_views']=data['Video views']/data['Video Uploads']

# %%
data
# Out:
#       Rank  Grade                Channel name  Video Uploads  Subscribers  Video views  Average_views
# 0        1      5                      Zee TV          82757     18752951  20869786591      252181.53
# 1        2      5                    T-Series          12661     61196302  47548839843     3755535.89
# 2        3      5  Cocomelon - Nursery Rhymes            373     19238251   9793305082    26255509.60
# 3        4      5                   SET India          27323     31180559  22675948293      829921.62
# 4        5      5                         WWE          36756     32852346  26273668433      714813.05
# ...    ...    ...                         ...            ...          ...          ...            ...
# 4995  4996      1              Uras Benlioğlu            706      2072942    441202795      624933.14
# 4996  4997      1           HI-TECH MUSIC LTD            797      1055091    377331722      473440.05
# ...

# %%
# find out top 5 channels with maximum number of video uploads

# %%
data.loc[data['Video Uploads'].sort_values(ascending=False).head().index]['Channel name']
# Out:
# 3453    AP Archive
# 1149      YTN NEWS
# 2223     SBS Drama
# 323       GMA News
# 2956           MLB
# Name: Channel name, dtype: object

# %%
# find coreleation matrix

# %%
data.corr(numeric_only=True)
# Out:
#                Grade  Video Uploads  Subscribers  Video views  Average_views
# Grade           1.00           0.09         0.43         0.48           0.16
# Video Uploads   0.09           1.00         0.01         0.09          -0.06
# Subscribers     0.43           0.01         1.00         0.79           0.29
# Video views     0.48           0.09         0.79         1.00           0.29
# Average_views   0.16          -0.06         0.29         0.29           1.00

# %%
# which grade has maximum number of video uploads

# %%
data['Video Uploads'].sort_values(ascending=False).max()
# Out:
# 422326

# %%
data.groupby('Grade')['Video Uploads'].mean()
# Out:
# Grade
# 1    3136.16
# 2    4382.58
# 3    5709.86
# 4   16960.30
# 5   37450.70
# Name: Video Uploads, dtype: float64

# %%
sns.barplot(x='Grade',y='Video Uploads',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Video Uploads'>

# %%
data[data['Grade']==5]
# Out:
#   Rank  Grade                Channel name  Video Uploads  Subscribers  Video views  Average_views
# 0    1      5                      Zee TV          82757     18752951  20869786591      252181.53
# 1    2      5                    T-Series          12661     61196302  47548839843     3755535.89
# 2    3      5  Cocomelon - Nursery Rhymes            373     19238251   9793305082    26255509.60
# 3    4      5                   SET India          27323     31180559  22675948293      829921.62
# 4    5      5                         WWE          36756     32852346  26273668433      714813.05
# 5    6      5                  Movieclips          30243     17149705  16618094724      549485.66
# 6    7      5                  netd müzik           8500     11373567  23898730764     2811615.38
# 7    8      5       ABS-CBN Entertainment         100147     12149206  17202609850      171773.59
# 8    9      5             Ryan ToysReview           1140     16082927  24518098041    21507103.54
# ...

# %%
# which grade has the higest average views

# %%
data.groupby('Grade')['Average_views'].mean()
# Out:
# Grade
# 1    3280380.88
# 2    5254804.04
# 3   10540908.45
# 4   11577080.32
# 5    5688267.96
# Name: Average_views, dtype: float64

# %%
sns.barplot(x='Grade',y='Average_views',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Average_views'>

# %%
# which grade has higest number of subscrbers

# %%
data.groupby('Grade')['Subscribers'].mean()
# Out:
# Grade
# 1    1535207.95
# 2    2798520.38
# 3    5107136.29
# 4   11726947.47
# 5   22281762.50
# Name: Subscribers, dtype: float64

# %%
sns.barplot(x='Grade',y='Subscribers',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Subscribers'>

# %%
sns.barplot(x='Grade',y='Video views',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Video views'>

# %%
data.groupby('Grade').mean(numeric_only=True)
# Out:
#        Video Uploads  Subscribers    Video views  Average_views
# Grade
# 1            3136.16   1535207.95   555183839.09     3280380.88
# 2            4382.58   2798520.38  1102450027.69     5254804.04
# 3            5709.86   5107136.29  2497972949.11    10540908.45
# 4           16960.30  11726947.47  6168741772.73    11577080.32
# 5           37450.70  22281762.50 21199091192.80     5688267.96
