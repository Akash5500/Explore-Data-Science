# %% [markdown]
# ### Syntax: Series.str.cat(others=None, sep=None, na_rep=None)
# Parameters:
# * others: Series, index, data frame or list of strings to concatenate
# * sep: Separator to be put between the two strings
# * na_rep: None or string value to replace in place of null values
# * Return type: Series with concatenated string values *

# %%
import pandas as pd

df=pd.read_csv('nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight            College     Salary
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas  7730337.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette  6796117.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University        NaN
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State  1148640.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN  5000000.0
# ..             ...             ...     ...      ...   ...    ...     ...                ...        ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler  2433333.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0                NaN   900000.0
# ...

# %%
new= df['Team'].copy()

# %%
df['Name']=df['Name'].str.cat(new, sep=',',na_rep='No information')

# %%
df
# Out:
#                               Name            Team  Number Position   Age Height  Weight            College     Salary
# 0     Avery Bradley,Boston Celtics  Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas  7730337.0
# 1       Jae Crowder,Boston Celtics  Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette  6796117.0
# 2      John Holland,Boston Celtics  Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University        NaN
# 3       R.J. Hunter,Boston Celtics  Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State  1148640.0
# 4     Jonas Jerebko,Boston Celtics  Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN  5000000.0
# ..                             ...             ...     ...      ...   ...    ...     ...                ...        ...
# 453         Shelvin Mack,Utah Jazz       Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler  2433333.0
# ...

# %% [markdown]
# ## index.append()
# ### Syntax:Index.append(other)
#
# Parameters :
# other : Index or list/tuple of indices
#
#
# Returns : Index

# %%
# importing pandas as pd
import pandas as pd

# Creating the first Index
df1 = pd.Index(['Jan', 'Feb', 'Mar', 'Apr'])

# Creating the second Index
df2 = pd.Index(['May', 'Jun', 'Jul', 'Aug'])

# Creating the third Index
df3 = pd.Index(['Sep', 'Oct', 'Nov', 'Dec'])

# Print the first, second and third Index
print(df1, "\n", df2, "\n", df3)
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr'], dtype='object')
#  Index(['May', 'Jun', 'Jul', 'Aug'], dtype='object')
#  Index(['Sep', 'Oct', 'Nov', 'Dec'], dtype='object')

# %%
# We pass df2 and df3 as a list of
# indexes to the append function
df1.append([df2, df3])
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec'],
#       dtype='object')

# %% [markdown]
# ## series.combine()
# ### Syntax: Series.combine(other, func, fill_value=nan)
#
# Parameters:
# other: other series or list type to be combined with caller series
# func: Function passed as parameter which will decide from which series the element should be put at that index
# fill_value: integer value of level in case of multi index
#
#
# Return: Combined series with same shape as caller series

# %%
# importing pandas module 
import pandas as pd 
  
# creating first series 
first =[1, 2, 5, 6, 3, 7, 11, 0, 4] 
  
# creating second series 
second =[5, 3, 2, 1, 3, 9, 21, 3, 1] 
  
# making series 
first = pd.Series(first) 
  
# making seriesa 
second = pd.Series(second) 
  
# calling .combine() method 
result = first.combine(second, (lambda x1, x2: x1 if x1 < x2 else x2)) 
  
# display 
result
# Out:
# 0     1
# 1     2
# 2     2
# 3     1
# 4     3
# 5     7
# 6    11
# 7     0
# 8     1
# dtype: int64

# %%
# importing pandas module 
import pandas as pd 

# making data frame 
df = pd.read_csv("nba.csv") 


df.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight            College      Salary
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas   7730337.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette   6796117.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University         NaN
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State   1148640.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN   5000000.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0                NaN  12000000.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0                LSU   1170960.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0            Gonzaga   2165160.0
# ...

# %%
# new_row = pd.DataFrame({'Name':'Geeks', 'Team':'Boston', 'Number':3,
# 						'Position':'PG', 'Age':33, 'Height':'6-2',
# 						'Weight':189, 'College':'MIT', 'Salary':99999},
# 															index =[0])
# # simply concatenate both dataframes
# df = pd.concat([df,new_row]).reset_index(drop = True)
# df.tail(5)



new_row = pd.DataFrame({'Name':'Geeks', 'Team':'Boston', 'Number':3,
                        'Position':'PG', 'Age':33, 'Height':'6-2',
                        'Weight':189, 'College':'MIT', 'Salary':99999}, index=[4])
 
df = pd.concat([df.iloc[:4],new_row,df.iloc[4:]], ignore_index=True)
df.head(n=10)
# Out:
#             Name            Team  Number Position   Age Height  Weight            College      Salary
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas   7730337.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette   6796117.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University         NaN
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State   1148640.0
# 4          Geeks          Boston     3.0       PG  33.0    6-2   189.0                MIT     99999.0
# 5  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN   5000000.0
# 6   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0                NaN  12000000.0
# 7  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0                LSU   1170960.0
# ...

# %% [markdown]
# ### Syntax: Series.str.join(sep)
#
#
# Parameters:
# sep: string value, joins elements with the string between them
#
# Return type: Series with joined elements

# %%
# importing pandas module 
import pandas as pd 
	
# reading csv file from url 
data = pd.read_csv("nba.csv") 

# dropping null value columns to avoid errors 
data.dropna(inplace = True) 
	
# joining string and overwriting 
data["Name"]= data["Name"].str.join("-") 

# display 
data
# Out:
#                           Name            Team  Number Position   Age Height  Weight        College     Salary
# 0    A-v-e-r-y- -B-r-a-d-l-e-y  Boston Celtics     0.0       PG  25.0    6-2   180.0          Texas  7730337.0
# 1        J-a-e- -C-r-o-w-d-e-r  Boston Celtics    99.0       SF  25.0    6-6   235.0      Marquette  6796117.0
# 3        R-.-J-.- -H-u-n-t-e-r  Boston Celtics    28.0       SG  22.0    6-5   185.0  Georgia State  1148640.0
# 6    J-o-r-d-a-n- -M-i-c-k-e-y  Boston Celtics    55.0       PF  21.0    6-8   235.0            LSU  1170960.0
# 7      K-e-l-l-y- -O-l-y-n-y-k  Boston Celtics    41.0        C  25.0    7-0   238.0        Gonzaga  2165160.0
# ..                         ...             ...     ...      ...   ...    ...     ...            ...        ...
# 449      R-o-d-n-e-y- -H-o-o-d       Utah Jazz     5.0       SG  23.0    6-8   206.0           Duke  1348440.0
# ...

# %%
# importing pandas module 
import pandas as pd 
	
# reading csv file from url 
data = pd.read_csv("nba.csv")

# dropping null value columns to avoid errors 
data.dropna(inplace = True) 
data

# %%
data['Team']=data["Team"].str.split(' ')
data
# Out:
#               Name               Team  Number Position   Age Height  Weight        College     Salary
# 0    Avery Bradley  [Boston, Celtics]     0.0       PG  25.0    6-2   180.0          Texas  7730337.0
# 1      Jae Crowder  [Boston, Celtics]    99.0       SF  25.0    6-6   235.0      Marquette  6796117.0
# 3      R.J. Hunter  [Boston, Celtics]    28.0       SG  22.0    6-5   185.0  Georgia State  1148640.0
# 6    Jordan Mickey  [Boston, Celtics]    55.0       PF  21.0    6-8   235.0            LSU  1170960.0
# 7     Kelly Olynyk  [Boston, Celtics]    41.0        C  25.0    7-0   238.0        Gonzaga  2165160.0
# ..             ...                ...     ...      ...   ...    ...     ...            ...        ...
# 449    Rodney Hood       [Utah, Jazz]     5.0       SG  23.0    6-8   206.0           Duke  1348440.0
# 451  Chris Johnson       [Utah, Jazz]    23.0       SF  26.0    6-6   206.0         Dayton   981348.0
# ...

# %%
data['Team']=data['Team'].str.join('-')
data
# Out:
#               Name                         Team  Number Position   Age Height  Weight            College     Salary
# 0    Avery Bradley  B-o-s-t-o-n- -C-e-l-t-i-c-s     0.0       PG  25.0    6-2   180.0              Texas  7730337.0
# 1      Jae Crowder  B-o-s-t-o-n- -C-e-l-t-i-c-s    99.0       SF  25.0    6-6   235.0          Marquette  6796117.0
# 2     John Holland  B-o-s-t-o-n- -C-e-l-t-i-c-s    30.0       SG  27.0    6-5   205.0  Boston University        NaN
# 3      R.J. Hunter  B-o-s-t-o-n- -C-e-l-t-i-c-s    28.0       SG  22.0    6-5   185.0      Georgia State  1148640.0
# 4    Jonas Jerebko  B-o-s-t-o-n- -C-e-l-t-i-c-s     8.0       PF  29.0   6-10   231.0                NaN  5000000.0
# ..             ...                          ...     ...      ...   ...    ...     ...                ...        ...
# 453   Shelvin Mack            U-t-a-h- -J-a-z-z     8.0       PG  26.0    6-3   203.0             Butler  2433333.0
# ...

# %%
# importing pandas module 
import pandas as pd 
	
# reading csv file from url 
data = pd.read_csv("nba.csv")

# data['New']=df['Name']+' '+df['Team']
data['new_second']=data[['Name','College']].apply(lambda x1: ' '.join(x1), axis=1)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 8
#       5 data = pd.read_csv("nba.csv")
#       7 # data['New']=df['Name']+' '+df['Team']
# ----> 8 data['new_second']=data[['Name','College']].apply(lambda x1: ' '.join(x1), axis=1)
#       9 data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# ...

# %%
import pandas as pd

# reading csv file from url
data = pd.read_csv("nba.csv")
data.dropna(inplace=True)

# Creating a new column 'new_second' by combining 'Name' and 'College'
# data['new_second'] = data[['Name', 'College']].apply(lambda x: ' '.join(x), axis=1)
data['new_second'] = data[['Name', 'Age']].astype(str).apply(lambda x: ' '.join(x), axis=1)



# Display the DataFrame with the new column
data
# Out:
#               Name            Team  Number Position   Age Height  Weight        College     Salary          new_second
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0          Texas  7730337.0  Avery Bradley 25.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0      Marquette  6796117.0    Jae Crowder 25.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0  Georgia State  1148640.0    R.J. Hunter 22.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0            LSU  1170960.0  Jordan Mickey 21.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0        Gonzaga  2165160.0   Kelly Olynyk 25.0
# ..             ...             ...     ...      ...   ...    ...     ...            ...        ...                 ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0           Duke  1348440.0    Rodney Hood 23.0
# ...

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.0.3

# %% [markdown]
# ## df.compare()
#
# ### DataFrame.compare(other, align_axis=1, keep_shape=False, keep_equal=False)
#
#
# other: The DataFrame to compare with.
#
# align_axis: The axis along which the comparison should be done. It can be 0 (rows), 1 (columns), or None (both). The default is 1.
#
# keep_shape: If True, the resulting DataFrame will have the same shape as the original DataFrames, filling in missing values with NaN. If False, the resulting DataFrame will only contain differences. The default is False.
#
# keep_equal: If True, the resulting DataFrame will include entries that are equal in both DataFrames. If False, only differing entries will be included. The default is False.

# %%
# pandas version == 1.1.0 (min) 
import pandas as pd 
import numpy as np 

# create your first DataFrame 
# using pd.DataFrame 
first_df = pd.DataFrame( 
	{ 
		"Stationary": ["Pens", "Scales", 
					"Pencils", "Geometry Box", 
					"Crayon Set"], 
		"Price": [100, 50, 25, 100, 65], 
		"Quantity": [10, 5, 5, 2, 1] 
	}) 
# Display the df 
first_df
# Out:
#      Stationary  Price  Quantity
# 0          Pens    100        10
# 1        Scales     50         5
# 2       Pencils     25         5
# 3  Geometry Box    100         2
# 4    Crayon Set     65         1

# %%
second_df=first_df.copy()

# %%
second_df.loc[0, 'Price'] = 150 
second_df.loc[1, 'Price'] = 70
second_df.loc[2, 'Price'] = 30
second_df.loc[0, 'Quantity'] = 15
second_df.loc[1, 'Quantity'] = 7
second_df.loc[2, 'Quantity'] = 6

# %%
second_df
# Out:
#      Stationary  Price  Quantity
# 0          Pens    150        15
# 1        Scales     70         7
# 2       Pencils     30         6
# 3  Geometry Box    100         2
# 4    Crayon Set     65         1

# %%
first_df.compare(second_df)
# Out:
#    Price        Quantity
#     self  other     self other
# 0  100.0  150.0     10.0  15.0
# 1   50.0   70.0      5.0   7.0
# 2   25.0   30.0      5.0   6.0

# %%
first_df.compare(second_df,align_axis=1,keep_shape=True, keep_equal=True, )
# Out:
#      Stationary               Price       Quantity
#            self         other  self other     self other
# 0          Pens          Pens   100   150       10    15
# 1        Scales        Scales    50    70        5     7
# 2       Pencils       Pencils    25    30        5     6
# 3  Geometry Box  Geometry Box   100   100        2     2
# 4    Crayon Set    Crayon Set    65    65        1     1

# %%
first_df.compare(second_df,keep_shape=True, keep_equal=True)
# Out:
#      Stationary               Price       Quantity
#            self         other  self other     self other
# 0          Pens          Pens   100   150       10    15
# 1        Scales        Scales    50    70        5     7
# 2       Pencils       Pencils    25    30        5     6
# 3  Geometry Box  Geometry Box   100   100        2     2
# 4    Crayon Set    Crayon Set    65    65        1     1

# %%
display(first_df)
display(second_df)
# Out:
#      Stationary  Price  Quantity
# 0          Pens    100        10
# 1        Scales     50         5
# 2       Pencils     25         5
# 3  Geometry Box    100         2
# 4    Crayon Set     65         1
#      Stationary  Price  Quantity
# 0          Pens    150        15
# 1        Scales     70         7
# 2       Pencils     30         6
# 3  Geometry Box    100         2
# 4    Crayon Set     65         1

# %%
s1=first_df['Price']
s1
# Out:
# 0    100
# 1     50
# 2     25
# 3    100
# 4     65
# Name: Price, dtype: int64

# %%
s2=second_df['Price']
s2
# Out:
# 0    150
# 1     70
# 2     30
# 3    100
# 4     65
# Name: Price, dtype: int64

# %%
print(s1!=s2)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Price, dtype: bool

# %%
print(s1.equals(s2))
# Out:
# False

# %%
from datetime import date
d=date(2000,12,4)
d
# Out:
# datetime.date(2000, 12, 4)

# %%
import pandas as pd 

timestamp=pd.Timestamp('2023-10-04 15:30:00')

all_=timestamp.quarter
all_
# Out:
# 4

# %%
time_period=pd.Period('2023-10-04', freq='M')

# %% [markdown]
# ## pd.Timestamp()
#
# ### pd.Timestamp(ts_input, tz=None, unit=None, year=None, month=None, day=None, hour=None, minute=None, second=None, microsecond=None)
#
# * ts_input: The input data to convert to a timestamp. It can be a string, datetime object, or a numeric value representing seconds since the epoch.
#
# * tz: An optional time zone parameter.
#
# * unit: An optional string parameter that specifies the unit of the input data. For example, 's' for seconds, 'ms' for milliseconds, 'us' for microseconds.
#
# * year, month, day, hour, minute, second, microsecond: Optional parameters that can be used to specify individual components of the timestamp.

# %%
timestamp = pd.Timestamp('2023-10-04 15:30:00',tz='America/New_York')
timestamp
# Out:
# Timestamp('2023-10-04 15:30:00-0400', tz='America/New_York')

# %%
utc_timestamp=timestamp.tz_convert('UTC')
utc_timestamp
# Out:
# Timestamp('2023-10-04 19:30:00+0000', tz='UTC')

# %%
original_timestamp=utc_timestamp.tz_convert('America/New_York')
original_timestamp
# Out:
# Timestamp('2023-10-04 15:30:00-0400', tz='America/New_York')

# %%
datetime_index = pd.DatetimeIndex(['2023-10-04',
                                   '2023-10-11', 
                                   '2023-10-18'],
                                  tz='Asia/Shanghai')
datetime_index
# Out:
# DatetimeIndex(['2023-10-04 00:00:00+08:00', '2023-10-11 00:00:00+08:00',
#                '2023-10-18 00:00:00+08:00'],
#               dtype='datetime64[ns, Asia/Shanghai]', freq=None)

# %%
import pandas as pd

# Create dates dataframe with frequency 
data = pd.date_range('1/1/2011', periods = 10, freq ='H')

data
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
# Create date and time with dataframe
data = pd.date_range('1/1/2011', periods = 10, freq ='H')

x = pd.Timestamp.now()
x.month, x.year, x.hour,x. minute, x.day, x.week,x.weekday(),x.quarter,x.microsecond
# Out:
# (12, 2023, 14, 22, 27, 52, 2, 4, 781710)

# %%
rng=pd.DataFrame()

rng['Date']=pd.date_range('1/1/2011', periods = 72, freq ='H')

rng['Year']=rng['Date'].dt.year
rng['Month']=rng['Date'].dt.month
rng['Day']=rng['Date'].dt.day
rng['Hour']=rng['Date'].dt.hour
rng['minutes']=rng['Date'].dt.minute

# %% [markdown]
# ### Syntax : Timestamp.timestamp()
#
# Parameters : None
#
#
# Return : number of seconds since zero moment

# %%
import pandas as pd

# Create a Timestamp object
timestamp = pd.Timestamp("2022-10-12 12:30:45")

# Convert to Unix time
unix_time = timestamp.timestamp()

print("Unix Time:", unix_time)
# Out:
# Unix Time: 1665577845.0

# %%
ts = pd.Timestamp(year = 2011,  month = 11, day = 21, 
                  hour = 10, second = 49, tz = 'US/Central') 
ts
ts.timetz()
# Out:
# datetime.time(10, 0, 49, tzinfo=<DstTzInfo 'US/Central' CST-1 day, 18:00:00 STD>)

# %%
ts=pd.Timestamp('2023-01-15 10:30:00',tz="Asia/Tokyo")
unix_time=ts.timestamp()
unix_time
# Out:
# 1673746200.0

# %%
# importing pandas as pd
import pandas as pd

# Create the Timestamp object
ts = pd.Timestamp(year = 2009, month = 5, day = 31, 
				hour = 4, second = 49, tz = 'Europe/Berlin')

# Print the Timestamp object
print(ts)
# Out:
# 2009-05-31 04:00:49+02:00

# %%
t=pd.Timestamp.now()
t.year,t.quarter,t.hour
# Out:
# (2023, 4, 16)

# %% [markdown]
# ### pd.date_range(start=None, end=None, periods=None, freq=None, tz=None, normalize=False, name=None, closed=None, **kwargs)
#
# * start: The starting date. Can be a string, datetime, Timestamp, or any convertible type. The default is None.
#
# * end: The ending date. Can be a string, datetime, Timestamp, or any convertible type. The default is None.
#
# * periods: The number of periods to generate. Either end or periods must be specified. The default is None.
#
# * freq: The frequency of the data. This can be a string like 'D' for day, 'H' for hour, 'M' for month, etc. The default is None, meaning that start, end, and periods should be specified instead.
#
# * tz: Time zone name for returning localized DatetimeIndex, for example, 'UTC' or 'US/Eastern'.
#
# * normalize: If True, normalize the dates by setting the time part to midnight. The default is False.
#
# * name: The name of the resulting DatetimeIndex. The default is None.
#
# * closed: Make the interval closed on the 'right', 'left', 'both', or None. The default is None.
#
# **kwargs: Additional arguments to be passed to the constructor of the DatetimeIndex.*

# %%
import pandas as pd 

timestamp=pd.date_range(end=pd.Timestamp.now(),periods=7,freq='D',)
data={
    "temperature": [21.2, 23.2, 27.2, 29.2, 31.2,28.3,21.4],
    "humidity": [43, 58, 54, 34, 47, 56, 40]} 


df=pd.DataFrame(data,index=timestamp)
df
# Out:
#                             temperature  humidity
# 2023-12-21 16:24:04.273442         21.2        43
# 2023-12-22 16:24:04.273442         23.2        58
# 2023-12-23 16:24:04.273442         27.2        54
# 2023-12-24 16:24:04.273442         29.2        34
# 2023-12-25 16:24:04.273442         31.2        47
# 2023-12-26 16:24:04.273442         28.3        56
# 2023-12-27 16:24:04.273442         21.4        40

# %%
import pandas as pd
 
# Create a Timestamp object in ISO format
time_stamp_obj = pd.Timestamp('2015-06-26 07:35:00', tz='Asia/Kolkata')
time_stamp_obj.isoformat()
# Out:
# '2015-06-26T07:35:00+05:30'

# %%
t=pd.Timestamp.now()
t.date()
# Out:
# datetime.date(2023, 12, 27)

# %% [markdown]
# ### Syntax : Timestamp.replace()
#
# Parameters :
#
#
# year : int
#
# month : int
#
# day : int
#
# hour : int
#
# minute : int
#
# second : int
#
# microsecond : int
#
# nanosecond : int
#
# tzinfo : int
#
# fold : int
#
# Return : Timestamp with fields replaced

# %%
t=pd.Timestamp('2023-12-04')
ts=t.replace(year=2011)
ts
# Out:
# Timestamp('2011-12-04 00:00:00')

# %%
# importing pandas as pd
import pandas as pd

# Create the Timestamp object
ts = pd.Timestamp(year = 2009, month = 5, day = 31,
				hour = 4, second = 49, tz = 'Europe/Berlin')

# Print the Timestamp object
print(ts.now())
# Out:
# 2023-12-27 16:35:23.887679

# %% [markdown]
# ### Syntax: pandas.to_datetime(arg, errors=’raise’, dayfirst=False, yearfirst=False, utc=None, box=True, format=None, exact=True, unit=None, infer_datetime_format=False, origin=’unix’, cache=False)
#
# Parameters:
#
# * arg: This is the object to convert to a datetime. It can be a string, a series, or a list.
#
# * errors: Specifies how to handle parsing errors. Possible values are 'raise', 'coerce', and 'ignore'.
#
# * dayfirst: When parsing European-style dates with day first (e.g., 10/11/12), set this to True.
#
# * yearfirst: When parsing European-style dates with year first (e.g., 12/11/10), set this to True.
#
# * utc: If True, return UTC time. If False (default), return local time.
#
# * format: A string of the expected format of the date. This is only necessary if arg is a string.
#
# * exact: If True, requires an exact format match. If False (default), allows the format to match as long as the key elements are matched.
#
# * unit: The unit of the arg. Defaults to 'ns' for nanoseconds.
#
# * infer_datetime_format: If True, infer the datetime format based on the first non-null element.
#
# * origin: The timestamp from which to calculate an offset if the arg is a number.
#
# * cache: If True (default), use a cache of unique, converted dates to apply the

# %%
import pandas as pd

# date string
d_string = "2023-09-17 14:30:00"

# Convert the string to datetime
dt_obj = pd.to_datetime(d_string)

print(dt_obj)
# Out:
# 2023-09-17 14:30:00

# %%
import pandas as pd

# Sample numerical value representing seconds since the Unix epoch
unix_timestamp = 1721700500

# Convert to datetime using 's' (seconds) as the unit
dt_obj = pd.to_datetime(unix_timestamp,unit='s')

print(dt_obj)
# Out:
# 2024-07-23 02:08:20

# %%
import pandas as pd

df=pd.read_csv('todatetime.csv')
df.info
# Out:
# <bound method DataFrame.info of            Date      Time
# 0      8/6/1993  12:42 PM
# 1     3/31/1996   6:53 AM
# 2     4/23/1993  11:17 AM
# 3      3/4/2005   1:00 PM
# 4     1/24/1998   4:47 PM
# ..          ...       ...
# 995  11/23/2014   6:09 AM
# 996   1/31/1984   6:30 AM
# 997   5/20/2013  12:39 PM
# 998   4/20/2013   4:45 PM
# 999   5/15/2012   6:24 PM
#
# [1000 rows x 2 columns]>

# %%
df['Date']=pd.to_datetime(df['Date'],unit='s')
df['Time']= pd.to_datetime(df['Time'],unit='s')
df.dtypes
# Out:
# Date    datetime64[ns]
# Time    datetime64[ns]
# dtype: object

# %%
df
# Out:
#           Date                Time
# 0   1993-08-06 2023-12-27 12:42:00
# 1   1996-03-31 2023-12-27 06:53:00
# 2   1993-04-23 2023-12-27 11:17:00
# 3   2005-03-04 2023-12-27 13:00:00
# 4   1998-01-24 2023-12-27 16:47:00
# ..         ...                 ...
# 995 2014-11-23 2023-12-27 06:09:00
# 996 1984-01-31 2023-12-27 06:30:00
# 997 2013-05-20 2023-12-27 12:39:00
# 998 2013-04-20 2023-12-27 16:45:00
# 999 2012-05-15 2023-12-27 18:24:00
#
# [1000 rows x 2 columns]

# %%
# importing pandas as pd
import pandas as pd

per1 = pd.date_range(start ='1-1-2018', 
		end ='1-05-2018',periods=2, tz='Asia/Tokyo')

for val in per1:
	print(val)
# Out:
# 2018-01-01 00:00:00+09:00
# 2018-01-05 00:00:00+09:00

# %%
import pandas as pd

df=pd.read_csv('nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
new=df['College']

df['Name']=df['Name'].str.cat(new,sep='=')
df['Team']='ak_'+df['Team']+'_pk'
df['Weight']=df['Weight'].str.cat()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'College'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
new = df["Team"].("Boston Celtics", "  Boston Celtics  ").copy()

# %%
new.str.strip()=="  Boston Celtics  "
new
# Out:
# 0        Boston Celtics
# 1        Boston Celtics
# 2        Boston Celtics
# 3        Boston Celtics
# 4        Boston Celtics
#               ...
# 453             Utah Jazz
# 454             Utah Jazz
# 455             Utah Jazz
# 456             Utah Jazz
# 457                   NaN
# Name: Team, Length: 458, dtype: object

# %%
import pandas as pd 
 
# creating a series 
s = pd.Series(['a1', 'b2', 'c3'])

# %%
# Extracting a data
n= s.str.extract(r'([ab])(\d)')
 
print(n)
# Out:
#      0    1
# 0    a    1
# 1    b    2
# 2  NaN  NaN

# %%
# importing pandas module 
import pandas as pd 
 
# creating a series 
s = pd.Series(['a1', 'b2', 'c3'])
 
# Extracting a data
n = s.str.extract(r'(?P<Geeks>[ab])(?P<For>\d)')
 
print(n)
# Out:
#   Geeks  For
# 0     a    1
# 1     b    2
# 2   NaN  NaN

# %%
# importing pandas module 
import pandas as pd 
 
# creating a series 
s = pd.Series(['a1', 'b2', 'c3'])
 
# Extracting a data
n = s.str.extract(r'(?P<Geeks>[ab])(?P<For>\d)')
 
print(n)
# Out:
#   Geeks  For
# 0     a    1
# 1     b    2
# 2   NaN  NaN

# %%
import pandas as pd

# Creating a Pandas Series with product information
products = pd.Series(['Apple x3', 'Banana x2', 'Orange x5', 'Grapes x10'])

# Using str.extract to extract product name and quantity
product_info = products.str.extract(r'(?P<Product>\w+)\s*x\s*(?P<Quantity>\d+)')

# Printing the result
print(product_info)
# Out:
#   Product Quantity
# 0   Apple        3
# 1  Banana        2
# 2  Orange        5
# 3  Grapes       10

# %%
import re

# Regular expression with a named capturing group
pattern = r'(?P<word>\w+)'

# Example string
text = 'Hello, world!'

# Using re.search to find the match
match = re.search(pattern, text)

# Accessing the named capturing group
if match:
    captured_word = match.group('word')
    print(f"Captured word: {captured_word}")
# Out:
# Captured word: Hello

# %% [markdown]
# ## Syntax:Series.str.replace(pat, repl, n=-1, case=None, regex=True)
#
# Parameters:
# * pat: string or compiled regex to be replaced
# * repl: string or callable to replace instead of pat
# * n: Number of replacements to make in a single string, default is -1 which means all.
# * case: Takes boolean value to decide case sensitivity. Make false for case insensitivity
# * regex: Boolean value, if True assume that the passed pattern is a regex
#
# * Return Type:Series with replaced text values

# %% [markdown]
# import pandas as pd
# df=pd.read_csv('nba.csv')
# df

# %%
df['Team']=df['Team'].str.replace('boston','Akash',case=False)

new=df['Team']=='Akash Celtics'

res=df.where(new).dropna()
res
# Out:
#                Name           Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Akash Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Akash Celtics    99.0       SF  25.0    6-6   235.0
# 3       R.J. Hunter  Akash Celtics    28.0       SG  22.0    6-5   185.0
# 6     Jordan Mickey  Akash Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Akash Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Akash Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Akash Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Akash Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Akash Celtics     4.0       PG  27.0    5-9   185.0
# 12      Evan Turner  Akash Celtics    11.0       SG  27.0    6-7   220.0
# 13      James Young  Akash Celtics    13.0       SG  20.0    6-6   215.0
# 14     Tyler Zeller  Akash Celtics    44.0        C  26.0    7-0   253.0
#
# ...

# %% [markdown]
# ## Syntax: Series.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method=’pad’)
#
# Parameters :
# * to_replace : How to find the values that will be replaced.
# * value : Value to replace any values matching to_replace with.
# * inplace : If True, in place.
# * limit : Maximum size gap to forward or backward fill.
# * regex : Whether to interpret to_replace and/or value as regular expressions
# * method : The method to use when for replacement, when to_replace is a scalar, list or tuple and value is None.
#
# * Returns : Object after replacement.

# %%
# importing pandas as pd
import pandas as pd

# Creating the Series
sr = pd.Series([10, 25, 3, 11, 24, 6])

# Create the Index
index_ = ['Coca Cola', 'Sprite', 'Coke', 'Fanta', 'Dew', 'ThumbsUp']

# set the index
sr.index = index_

# Print the series
print(sr)
# Out:
# Coca Cola    10
# Sprite       25
# Coke          3
# Fanta        11
# Dew          24
# ThumbsUp      6
# dtype: int64

# %%
res=sr.replace(to_replace=3,value=1000)
res
# Out:
# Coca Cola      10
# Sprite         25
# Coke         1000
# Fanta          11
# Dew            24
# ThumbsUp        6
# dtype: int64

# %%
# importing pandas as pd
import pandas as pd

# Creating the Series
sr = pd.Series(['New York', 'Chicago', 'Toronto', 'Lisbon', 'Rio'])

# Create the Index
index_ = ['City 1', 'City 2', 'City 3', 'City 4', 'City 5'] 

# set the index
sr.index = index_

# Print the series
print(sr)
# Out:
# City 1    New York
# City 2     Chicago
# City 3     Toronto
# City 4      Lisbon
# City 5         Rio
# dtype: object

# %%
res=sr.replace(to_replace=['New York', 'Rio'],value=['London', 'Brisbane'])
res
# Out:
# City 1      London
# City 2     Chicago
# City 3     Toronto
# City 4      Lisbon
# City 5    Brisbane
# dtype: object

# %% [markdown]
# ## pandas.tseries.offsets.DateOffset(n=1, normalize=False, year=0, month=0, day=0, weekday=None, weekday_offset=0, days=None, months=None, years=None)
#
# * n: Number of offset periods. Default is 1. If negative, it represents subtraction.
#
# * normalize: If True, normalize the result by setting the time components (hours, minutes, seconds, and microseconds) to zero. Default is False.
#
# * year, month, day: Specific offsets for years, months, and days. If provided, these values will be added to the result.
#
# * weekday: Specific weekday to roll the date to. Values can be 0-6 (Monday to Sunday) or a string abbreviation (e.g., 'Mon', 'Tue'). If provided, the date will be rolled to the closest matching weekday.
#
# * weekday_offset: Number of offset weekdays to roll the date. If provided, the date will be rolled to the specified weekday offset.
#
# * days, months, years: Alternative parameters for specifying offsets in terms of days, months, and years.*

# %%
# importing pandas as pd
import pandas as pd

# Creating Timestamp
ts = pd.Timestamp('2019-10-10 07:15:11')

# Create the DateOffset
do = pd.tseries.offsets.DateOffset(days=-10,hour=2)

# Print the Timestamp
print(ts)

# Print the DateOffset
print(do)

# %%
# Adding the dateoffset to the given timestamp
new_timestamp = ts + do

# Print the updated timestamp
print(new_timestamp)
# Out:
# 2019-09-30 02:15:11

# %%
import pandas as pd

dates = pd.date_range('2023-12-20', periods=5, freq='D')
dates
# Out:
# DatetimeIndex(['2023-12-20', '2023-12-21', '2023-12-22', '2023-12-23',
#                '2023-12-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
offset = pd.DateOffset(days=3)
new_dates = dates + offset
print(new_dates)
# Out:
# DatetimeIndex(['2023-12-23', '2023-12-24', '2023-12-25', '2023-12-26',
#                '2023-12-27'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## pd.read_csv()
#
# ### pandas.read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, engine='c', dtype=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#
#
# Parameters:
# * filepath_or_buffer: The file path or object to read. This could be a file path, URL, or a file-like object (e.g., a StringIO object).
#
# * sep: The delimiter to use for separating fields. The default is ',' (comma).
#
# * header: Row(s) to use as the column names. The default is 'infer', which means the first row is used as headers.
#
# * names: List of column names to use. If not specified and header=None, column names will be generated automatically.
#
# * index_col: Column(s) to set as index (row labels).
#
# * usecols: Columns to select for loading. It can be a list of column names, a range of column names, or column indices.
#
# * dtype: Data type to force. If not specified, Pandas will attempt to infer the data types.
#
# * parse_dates: Columns to parse as dates. It can be a single column name or a list of column names.
#
# * na_values: Additional strings to recognize as NA/NaN. It can be a string, list, or dictionary.
#
# * encoding: Character encoding to use.
#
# * skiprows: Number of rows to skip at the beginning of the file.
#
# * nrows: Number of rows to read from the beginning of the file.
#
# * comment: Character to mark the start of comments.
#
# * quotechar: Character to denote the start and end of a quoted item.
#
# * skip_blank_lines: If True, skip over blank lines rather than interpreting them as *

# %%
import pandas as pd

df=pd.read_csv('nba.csv',sep=',',engine='python')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight            College     Salary
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas  7730337.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette  6796117.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University        NaN
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State  1148640.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN  5000000.0
# ..             ...             ...     ...      ...   ...    ...     ...                ...        ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler  2433333.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0                NaN   900000.0
# ...

# %%
df=pd.read_csv('nba.csv',sep=',',engine='python',header=0,index_col=['Name'])
df
# Out:
#                          Team  Number Position   Age Height  Weight            College     Salary
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas  7730337.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette  6796117.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University        NaN
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State  1148640.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN  5000000.0
# ...                       ...     ...      ...   ...    ...     ...                ...        ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler  2433333.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0                NaN   900000.0
# ...

# %%
res=df.groupby('Team')

# for name ,group in res:
#     print(name)
#     print(group)
#     print()
res

# %%
import numpy as np
res.aggregate(np.sum)
# Out:
#                         Number  ...       Salary
# Team                            ...
# Atlanta Hawks            285.0  ...   72902950.0
# Boston Celtics           478.0  ...   58541068.0
# Brooklyn Nets            274.0  ...   52528475.0
# Charlotte Hornets        257.0  ...   78340920.0
# Chicago Bulls            288.0  ...   86783378.0
# Cleveland Cavaliers      217.0  ...  106988689.0
# Dallas Mavericks         300.0  ...   71198732.0
# Denver Nuggets           229.0  ...   60121930.0
# Detroit Pistons          259.0  ...   67168263.0
# Golden State Warriors    313.0  ...   88868997.0
# Houston Rockets          220.0  ...   75283021.0
# Indiana Pacers           284.0  ...   66751826.0
# Los Angeles Clippers     293.0  ...   94854640.0
# Los Angeles Lakers       241.0  ...   71770431.0
# Memphis Grizzlies        280.0  ...   76550880.0
# Miami Heat               157.0  ...   82515673.0
# Milwaukee Bucks          320.0  ...   69603517.0
# ...

# %%
df=pd.read_csv('nba.csv',sep=',',engine='python',header=0,index_col=['Name'],nrows=10, skiprows=[1,3])
df
# Out:
#                            Team  Number Position   Age Height  Weight         College      Salary
# Name
# Jae Crowder      Boston Celtics    99.0       SF  25.0    6-6   235.0       Marquette   6796117.0
# R.J. Hunter      Boston Celtics    28.0       SG  22.0    6-5   185.0   Georgia State   1148640.0
# Jonas Jerebko    Boston Celtics     8.0       PF  29.0   6-10   231.0             NaN   5000000.0
# Amir Johnson     Boston Celtics    90.0       PF  29.0    6-9   240.0             NaN  12000000.0
# Jordan Mickey    Boston Celtics    55.0       PF  21.0    6-8   235.0             LSU   1170960.0
# Kelly Olynyk     Boston Celtics    41.0        C  25.0    7-0   238.0         Gonzaga   2165160.0
# Terry Rozier     Boston Celtics    12.0       PG  22.0    6-2   190.0      Louisville   1824360.0
# Marcus Smart     Boston Celtics    36.0       PG  22.0    6-4   220.0  Oklahoma State   3431040.0
# ...

# %%
# importing pandas as pd
import pandas as pd

# list of name, degree, score
nme = ["aparna", "pankaj", "sudhir", "Geeku"]
deg = ["MBA", "BCA", "M.Tech", "MBA"]
scr = [90, 40, 80, 98]

# dictionary of lists
dict = {'name': nme, 'degree': deg, 'score': scr}
	
df = pd.DataFrame(dict)

print(df)
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

# %%
df.to_csv('file1.csv', header=False, index=False,sep='\t')

# %% [markdown]
# ###  pandas.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, mangle_dupe_cols=True, **kwds)
#
# * io: This is the file path or object (like a file-like object or string). It can be the URL of an Excel file, a local file path, or a file-like object (e.g., a BytesIO object).
#
# * sheet_name: Specifies the sheet to read. It can be the sheet name, sheet index (0-indexed), or a list of sheet names or indices. Default is 0.
#
# * header: Row(s) to use as the column names. Default is 0.
#
# * names: List of column names to use. If not specified and header=None, column names will be generated automatically.
#
# * index_col: Column(s) to set as index (row labels).
#
# * usecols: Columns to select for loading. It can be a list of column names, a range of column names, or column indices.
#
# * parse_dates: Columns to parse as dates. It can be a single column name or a list of column names.
#
# * converters: Dict of functions for converting certain columns.
#
# * skiprows: Number of rows to skip at the beginning of the file.
#
# * nrows: Number of rows to read from the beginning of the file.
#
# * na_values: Additional strings to recognize as NA/NaN.
#
# * skipfooter: Number of lines at the end of the file to skip.
#
# * thousands: Thousands separator for parsing numbers.
#
# * comment: Character to mark the start of comments.
#
# * dtype: Data type to force. If not specified, Pandas will attempt to infer the data types.
#
# * engine: The engine to use. The default is 'xlrd', but other options include 'openpyxl' and 'odf'.*

# %%
import pandas as pd

df= pd.ExcelFile('Data-for-Practice.xlsx')
df.sheet_names
# Out:
# ['Problem', 'Reference Data', 'Solution']

# %%
import pandas as pd

# Specify the Excel file path
excel_file_path = 'Data-for-Practice.xlsx'

# Read each sheet into a separate DataFrame
sheet1_df = pd.read_excel(excel_file_path, sheet_name='Problem')
sheet2_df = pd.read_excel(excel_file_path, sheet_name='Reference Data')
sheet3_df = pd.read_excel(excel_file_path, sheet_name='Solution')

# Now you have three DataFrames: sheet1_df, sheet2_df, and sheet3_df

# %%
sheet3_df.shape
# Out:
# (91, 16)

# %%
# Read all sheets into a dictionary of DataFrames
all_sheets_dict = pd.read_excel(excel_file_path, sheet_name=None)

# Now all_sheets_dict is a dictionary where keys are sheet names and values are DataFrames

# %%
all_sheets_dict
# Out:
# {'Problem':     Unnamed: 0                             Unnamed: 1 Unnamed: 2  ... Unnamed: 7  Unnamed: 8 Unnamed: 9
#  0          NaN  Excel Data for Practice Free Download        NaN  ...        NaN         NaN        NaN
#  1          NaN                                    NaN        NaN  ...        NaN         NaN        NaN
#  2          NaN                                   Date  Sales Rep  ...   Profit %  Commission    Weekday
#  3          NaN                    2022-07-01 00:00:00        Ben  ...        NaN         NaN        NaN
#  4          NaN                    2022-07-01 00:00:00      Jacob  ...        NaN         NaN        NaN
#  ..         ...                                    ...        ...  ...        ...         ...        ...
#  86         NaN                    2022-08-29 00:00:00      Jacob  ...        NaN         NaN        NaN
#  87         NaN                    2022-08-30 00:00:00        Ben  ...        NaN         NaN        NaN
# ...

# %%
sheet3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   90 non-null     object
#  2   Unnamed: 2   89 non-null     object
#  3   Unnamed: 3   89 non-null     object
#  4   Unnamed: 4   89 non-null     object
#  5   Unnamed: 5   89 non-null     object
#  6   Unnamed: 6   89 non-null     object
#  7   Unnamed: 7   33 non-null     object
#  8   Unnamed: 8   89 non-null     object
#  9   Unnamed: 9   89 non-null     object
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  4 non-null      object
#  12  Unnamed: 12  19 non-null     object
#  13  Unnamed: 13  20 non-null     object
#  14  Unnamed: 14  18 non-null     object
#  15  Unnamed: 15  15 non-null     object
# dtypes: float64(2), object(14)
# memory usage: 11.5+ KB

# %%
# import pandas as pd 
import pandas as pd 

# Create a Pandas dataframe from some data. 
df = pd.DataFrame({'Data': ['Geeks', 'For', 'geeks', 'is', 
							'portal', 'for', 'geeks']}) 

# Create a Pandas Excel writer 
# object using XlsxWriter as the engine. 
writer = pd.ExcelWriter('pandasEx.xlsx', 
				engine ='xlsxwriter') 

# Write a dataframe to the worksheet. 
df.to_excel(writer, sheet_name ='Sheet1', index=False) 

# Close the Pandas Excel writer 
# object and output the Excel file. 
writer.up()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 18
#      14 df.to_excel(writer, sheet_name ='Sheet1', index=False)
#      16 # Close the Pandas Excel writer
#      17 # object and output the Excel file.
# ---> 18 writer.save()
#
# AttributeError: 'XlsxWriter' object has no attribute 'save'

# %%
# import pandas as pd 
import pandas as pd 

# Create a Pandas dataframe from some data. 
df = pd.DataFrame({'Data': ['Geeks', 'For', 'geeks', 'is', 
                            'portal', 'for', 'geeks']}) 

# Write the dataframe to an Excel file without using ExcelWriter
df.to_excel('pandasEx.xlsx', sheet_name='Sheet1', index=False)

# %%
df=pd.read_excel('pandasEx.xlsx')
df
# Out:
#      Data
# 0   Geeks
# 1     For
# 2   geeks
# 3      is
# 4  portal
# 5     for
# 6   geeks

# %%
# import pandas as pd 
import pandas as pd 


# Create some Pandas dataframes from some data. 
df1 = pd.DataFrame({'Data': [11, 12, 13, 14]}) 
df2 = pd.DataFrame({'Data': [21, 22, 23, 24]}) 
df3 = pd.DataFrame({'Data': [31, 32, 33, 34]}) 

# Create a Pandas Excel writer object 
# using XlsxWriter as the engine. 
writer = pd.ExcelWriter('pandas_multiple.xlsx', 
						engine ='xlsxwriter') 

# Write each dataframe to a different worksheet. 
df1.to_excel(writer, sheet_name ='Sheet1') 
df2.to_excel(writer, sheet_name ='Sheet2') 
df3.to_excel(writer, sheet_name ='Sheet3') 

# Close the Pandas Excel writer object 
# and output the Excel file. 
writer.close()

# %%
df=pd.ExcelFile('pandas_multiple.xlsx')
df.sheet_names
# Out:
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
res=pd.read_excel('pandas_multiple.xlsx',sheet_name=None)
res
# Out:
# {'Sheet1':    Unnamed: 0  Data
#  0           0    11
#  1           1    12
#  2           2    13
#  3           3    14,
#  'Sheet2':    Unnamed: 0  Data
#  0           0    21
#  1           1    22
#  2           2    23
#  3           3    24,
#  'Sheet3':    Unnamed: 0  Data
#  0           0    31
#  1           1    32
#  2           2    33
#  3           3    34}

# %% [markdown]
# ### DataFrame.to_excel(excel_writer, sheet_name='Sheet1', na_rep='', index=True, index_label=None, header=True, startrow=0, startcol=0, engine=None, merge_cells=True, encoding=None, inf_rep='inf', verbose=True, freeze_panes=None)
#
# * excel_writer: The Excel file path or existing ExcelWriter object.
# * sheet_name: Name of the sheet which will contain the DataFrame.
# * na_rep: String representation of NaN (default is an empty string).
# * index: Write row names (index). Set to False to exclude the index column.
# * index_label: Column label for index column.
# * header: Write column names (default is True).
# * startrow, startcol: Upper left cell row and column to dump data frame.
# * engine: Write engine to use ('xlsxwriter', 'openpyxl', 'odf', 'xls' - default is None, meaning 'xlsxwriter' for xlsx, 'xlwt' for xls).
# * merge_cells: Set to True to write merged cells (default is True).
# * encoding: Encoding to use for writing.
# * freeze_panes: Tuple specifying the rows and columns to freeze.*

# %%
# import pandas as pd 
import pandas as pd 


# Create some Pandas dataframes from some data. 
df1 = pd.DataFrame({'Data': [11, 12, 13, 14]}) 
df2 = pd.DataFrame({'Data': [21, 22, 23, 24]}) 
df3 = pd.DataFrame({'Data': [31, 32, 33, 34]}) 
df4 = pd.DataFrame({'Data': [41, 42, 43, 44]}) 

# Create a Pandas Excel writer object 
# using XlsxWriter as the engine. 
writer = pd.ExcelWriter('pandas_positioning.xlsx', 
							engine ='xlsxwriter') 

# write and Positioning the dataframes in the worksheet. 
# Default position, cell A1. 
df1.to_excel(writer, sheet_name ='Sheet1') 
df2.to_excel(writer, sheet_name ='Sheet1', startcol = 3, na_) 
df3.to_excel(writer, sheet_name ='Sheet1', startrow = 6) 

# It is also possible to write the 
# dataframe without the header and index. 
df4.to_excel(writer, sheet_name ='Sheet1', 
			startrow = 7, startcol = 4, 
			header = False, index = False) 

# Close the Pandas Excel writer object 
# and output the Excel file. 
writer.close()

# %%
res=pd.read_excel('pandas_positioning.xlsx', na_values='NAN')
res
# Out:
#    Unnamed: 0  Data  Unnamed: 2  Unnamed: 3  Data.1
# 0         0.0    11         NaN         0.0    21.0
# 1         1.0    12         NaN         1.0    22.0
# 2         2.0    13         NaN         2.0    23.0
# 3         3.0    14         NaN         3.0    24.0
# 4         NaN   NaN         NaN         NaN     NaN
# 5         NaN  Data         NaN         NaN     NaN
# 6         0.0    31         NaN         NaN    41.0
# 7         1.0    32         NaN         NaN    42.0
# 8         2.0    33         NaN         NaN    43.0
# 9         3.0    34         NaN         NaN    44.0

# %%
import pandas as pd 
   
# from datetime module import 
# datetime and date method 
from datetime import datetime, date 
   
# Create a Pandas dataframe from some datetime data. 
# datetime(year,month,date,hour,minute,second) 
# date(year,month,date) 
dataframe = pd.DataFrame({ 
    'Date and time': [ datetime(2018, 1, 11, 11, 30, 55), 
                      datetime(2018, 2, 12, 1,  20, 33), 
                      datetime(2018, 3, 13, 11, 10    ), 
                      datetime(2018, 4, 14, 16, 45, 35), 
                      datetime(2018, 5, 15, 12, 10, 15)], 
                      
   'Dates only':    [ date(2018, 6, 21), 
                      date(2018, 7, 22), 
                      date(2018, 8, 23), 
                      date(2018, 9, 24), 
                      date(2018, 10, 25) ], }) 
dataframe
# Out:
#         Date and time  Dates only
# 0 2018-01-11 11:30:55  2018-06-21
# 1 2018-02-12 01:20:33  2018-07-22
# 2 2018-03-13 11:10:00  2018-08-23
# 3 2018-04-14 16:45:35  2018-09-24
# 4 2018-05-15 12:10:15  2018-10-25

# %%
writer_object = pd.ExcelWriter("Example_datetime.xlsx", 
                        engine ='xlsxwriter', 
                        datetime_format ='mmm d yyyy hh:mm:ss', 
                        date_format ='mmmm dd yyyy')

# %%
dataframe.to_excel(writer_object,sheet_name='Sheet1')
worksheet_object  = writer_object.sheets['Sheet1'] 
   
# set width of the B and C column 
worksheet_object.set_column('B:C', 20) 
   
writer_object.close()
# Out:
# C:\Users\akash\anaconda3\Lib\site-packages\xlsxwriter\workbook.py:368: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
ex=pd.read_excel("Example_datetime.xlsx")
ex
# Out:
#    Unnamed: 0       Date and time Dates only
# 0           0 2018-01-11 11:30:55 2018-06-21
# 1           1 2018-02-12 01:20:33 2018-07-22
# 2           2 2018-03-13 11:10:00 2018-08-23
# 3           3 2018-04-14 16:45:35 2018-09-24
# 4           4 2018-05-15 12:10:15 2018-10-25

# %%
# import pandas lib as pd 
import pandas as pd 

# Create a Pandas dataframe from some data. 
dataframe = pd.DataFrame( 
	{'Marks (Out of 50)': [30, 40, 45, 15, 8, 5, 35], 
	'Percentage': [.6, .8, .9, .3, .16, .1, .7 ], }) 

# Create a Pandas Excel writer 
# object using XlsxWriter as the engine. 
writer_object = pd.ExcelWriter("Example_column.xlsx", 
								engine ='xlsxwriter') 

# Write a dataframe to the worksheet. 
dataframe.to_excel(writer_object, sheet_name ='Sheet1') 

# Create xlsxwriter workbook object . 
workbook_object = writer_object.book 

# Create xlsxwriter worksheet object 
worksheet_object = writer_object.sheets['Sheet1'] 

# Create a new Format object to formats cells 
# in worksheets using add_format() method . 

# number taken upto 2 decimal places 
# format object is create. 
format_object1 = workbook_object.add_format({'num_format': '# 0.00'}) 

# Integral percentage format object is create. 
format_object2 = workbook_object.add_format({'num_format': '0 %'}) 

# Note: It isn't possible to format 
# any cells that already have a format 
# such as the index or headers or any 
# cells that contain dates or datetimes. 

# Set the column width and format. 
worksheet_object.set_column('B:B', 20, format_object1) 

# Set the column width and format. 
worksheet_object.set_column('C:C', 15, format_object2) 

# Close the Pandas Excel writer 
# object and output the Excel file. 
writer_object.close()

# %%
# import pandas lib as pd 
import pandas as pd 
   
   
data1 = ["Math", "Physics", "Computer", 
         "Hindi", "English", "chemistry"] 
data2 = [95, 78, 80, 80, 60, 95] 
data3 = [90, 67, 78, 70, 63, 90] 
   
# Create a Pandas dataframe from some data. 
dataframe = pd.DataFrame( 
    {'Subject': data1, 
     'Mid Term Exam Scores Out of 100' : data2, 
     'End Term Exam Scores Out of 100' : data3}) 
   
writer_obj=pd.ExcelWriter('Example_header.xlsx',engine='xlsxwriter')

dataframe.to_excel(writer_obj,sheet_name='Sheet1',startrow = 1, header = False)

workbook_object = writer_object.book 
worksheet_object = writer_object.sheets['Sheet1'] 

header_format_object = workbook_object.add_format({ 
                                'bold': True, 
                                'italic' : True, 
                                'text_wrap': True, 
                                'valign': 'top', 
                                'font_color': 'red', 
                                'border': 2})
for col_number, value in enumerate(dataframe.columns.values): 
    worksheet_object.write(0, col_number + 1, value,  
                              header_format_object) 


writer_obj.close()

# %%
# import pandas library as pd 
import pandas as pd 

# Create a Pandas dataframe from some data. 
dataframe = pd.DataFrame({ 
					'Subject': ["Math", "Physics", "Computer", 
								"Hindi", "English", "chemistry"], 
				'Mid Exam Score' : [90, 78, 60, 80, 60, 90], 
				'End Exam Score' : [45, 39, 30, 40, 30, 60] }) 

# Create a Pandas Excel writer 
# object using XlsxWriter as the engine. 
writer_object = pd.ExcelWriter('pandas_column_chart.xlsx', 
									engine ='xlsxwriter') 

# Write a dataframe to the worksheet. 
dataframe.to_excel(writer_object, sheet_name ='Sheet1') 

# Create xlsxwriter workbook object . 
workbook_object = writer_object.book 

# Create xlsxwriter worksheet object 
worksheet_object = writer_object.sheets['Sheet1'] 

# set width of the B and C column 
worksheet_object.set_column('B:C', 20) 

# Create a chart object that can be added 
# to a worksheet using add_chart() method. 
	
# here we create a column chart object . 
chart_object = workbook_object.add_chart({'type': 'column'}) 

# Add a data series to a chart 
# using add_series method. 

# Configure the first series. 
# syntax to define ranges is : 
# [sheetname, first_row, first_col, last_row, last_col]. 
chart_object.add_series({ 
	'name':	 ['Sheet1', 0, 2], 
	'categories': ['Sheet1', 1, 3, 6, 3], 
	'values':	 ['Sheet1', 1, 2, 6, 2], 
	}) 

# Configure a second series. 
chart_object.add_series({ 
	'name':	 ['Sheet1', 0, 1], 
	'categories': ['Sheet1', 1, 3, 6, 3], 
	'values':	 ['Sheet1', 1, 1, 6, 1], 
	}) 

# Add a chart title. 
chart_object.set_title({'name': 'Exam Score Distribution'}) 

# Add x-axis label 
chart_object.set_x_axis({'name': 'Subjects'}) 
	
# Add y-axis label 
chart_object.set_y_axis({'name': 'Marks'}) 

# add chart to the worksheet with given 
# offset values at the top-left corner of 
# a chart is anchored to cell E2 
worksheet_object.insert_chart('E2', chart_object, 
				{'x_offset': 20, 'y_offset': 5}) 

# Close the Pandas Excel writer 
# object and output the Excel file. 
writer_object.close()

# %% [markdown]
# # Data  Visualization

# %%
import pandas as pd
import numpy as np

df1=pd.read_csv('df1.csv', index_col=0)
df2=pd.read_csv('df2')
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt 
plt.style.use('ggplot') 
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('bmh') 
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('dark_background') 
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'A'}>, <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'C'}>, <Axes: title={'center': 'D'}>]],
#       dtype=object)

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
# Python program to convert 
# CSV to HTML Table


import pandas as pd

# to read csv file named "samplee"
a = pd.read_csv("nba.csv")

# to save as html file
# named as "Table"
a.to_html("Table.htm")

# assign it to a 
# variable (string)
html_file = a.to_html()

# %%
html_file
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Name</th>\n      <th>Team</th>\n      <th>Number</th>\n      <th>Position</th>\n      <th>Age</th>\n      <th>Height</th>\n      <th>Weight</th>\n      <th>College</th>\n      <th>Salary</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Avery Bradley</td>\n      <td>Boston Celtics</td>\n      <td>0.0</td>\n      <td>PG</td>\n      <td>25.0</td>\n      <td>6-2</td>\n      <td>180.0</td>\n      <td>Texas</td>\n      <td>7730337.0</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Jae Crowder</td>\n      <td>Boston Celtics</td>\n      <td>99.0</td>\n      <td>SF</td>\n      <td>25.0</td>\n      <td>6-6</td>\n      <td>235.0</td>\n      <td>Marquette</td>\n      <td>6796117.0</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>John Holland</td>\n      <td>Boston Celtics</td>\n      <td>30.0</td>\n      <td>SG</td>\n      <td>27.0</td>\n     
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from prettytable import PrettyTable
#       4 # open csv file
#       5 a = open("read_file.csv", 'r')
#
# ModuleNotFoundError: No module named 'prettytable'
