# %% [markdown]
# # CASE STUDY-1

# %% [markdown]
# ### Get the data set from below link
# https://www.kaggle.com/datasets/kaggle/sf-salaries

# %% [markdown]
# #### Import dataset and display top 10 rows

# %%
import pandas as pd

df=pd.read_csv('Salaries.csv')
df

# %%
df.head(n=10)
# Out:
#    Id        EmployeeName                                        JobTitle    BasePay  ...  Year Notes         Agency  Status
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18  ...  2011   NaN  San Francisco     NaN
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)  155966.02  ...  2011   NaN  San Francisco     NaN
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)  212739.13  ...  2011   NaN  San Francisco     NaN
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0  ...  2011   NaN  San Francisco     NaN
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6  ...  2011   NaN  San Francisco     NaN
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II   118602.0  ...  2011   NaN  San Francisco     NaN
# ...

# %% [markdown]
# #### Dispaly Bottom 10 rows

# %%
df.tail(n=10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  ...  Year Notes         Agency  Status
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00  ...  2014   NaN  San Francisco      PT
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00  ...  2014   NaN  San Francisco      PT
# 148646  148647      Not provided                  Not provided  Not Provided  ...  2014   NaN  San Francisco     NaN
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00  ...  2014   NaN  San Francisco      PT
# 148648  148649       Leon Walker                     Custodian          0.00  ...  2014   NaN  San Francisco      PT
# 148649  148650     Roy I Tillery                     Custodian          0.00  ...  2014   NaN  San Francisco      PT
# 148650  148651      Not provided                  Not provided  Not Provided  ...  2014   NaN  San Francisco     NaN
# ...

# %% [markdown]
# #### dispaly rows and columns in data set

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# #### Dispaly data types of all colums

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# ####  find the null value count in each row

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# #### dropping the rows whic are not reuired for analysis

# %%
df.drop(['Id','Agency','Status','Notes'],axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %%
df.head(10)
# Out:
#          EmployeeName                                        JobTitle    BasePay  ...   TotalPay TotalPayBenefits  Year
# 0      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18  ...  567595.43        567595.43  2011
# 1        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)  155966.02  ...  538909.28        538909.28  2011
# 2      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)  212739.13  ...  335279.91        335279.91  2011
# 3   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0  ...  332343.61        332343.61  2011
# 4     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6  ...  326373.19        326373.19  2011
# 5      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II   118602.0  ...  316285.74        316285.74  2011
# 6           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01  ...  315981.05        315981.05  2011
# ...

# %%
df.describe(include='all')
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  ...  Benefits       TotalPay  TotalPayBenefits           Year
# count        148654            148654  148049.0     148654.0  ...  112495.0  148654.000000     148654.000000  148654.000000
# unique       110811              2159  109900.0      66555.0  ...   99635.0            NaN               NaN            NaN
# top       Kevin Lee  Transit Operator       0.0          0.0  ...       0.0            NaN               NaN            NaN
# freq             13              7036     875.0      66103.0  ...    1053.0            NaN               NaN            NaN
# mean            NaN               NaN       NaN          NaN  ...       NaN   74768.321972      93692.554811    2012.522643
# std             NaN               NaN       NaN          NaN  ...       NaN   50517.005274      62793.533483       1.117538
# ...

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %% [markdown]
# #### count top 5 most occured employeee

# %%
df['EmployeeName'].value_counts().head(5)
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %% [markdown]
# #### Uniqure values in jobtitile

# %%
df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %% [markdown]
# #### number of unique values in jobtitle

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# #### find all the details of employees whoes title cotains 'Captain'

# %%
df[df['JobTitle'].str.contains('Captain',case=False)]
# Out:
#               EmployeeName                               JobTitle    BasePay  ...   TotalPay TotalPayBenefits  Year
# 1             GARY JIMENEZ        CAPTAIN III (POLICE DEPARTMENT)  155966.02  ...  538909.28        538909.28  2011
# 2           ALBERT PARDINI        CAPTAIN III (POLICE DEPARTMENT)  212739.13  ...  335279.91        335279.91  2011
# 11        PATRICIA JACKSON        CAPTAIN III (POLICE DEPARTMENT)    99722.0  ...  297608.92        297608.92  2011
# 17          SEBASTIAN WONG  CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87  ...  278569.21        278569.21  2011
# 22           GEORGE GARCIA              CAPTAIN, FIRE SUPPRESSION  140546.88  ...  273702.71        273702.71  2011
# ...                    ...                                    ...        ...  ...        ...              ...   ...
# 116604   Gregory L Stewart              Captain, Fire Suppression   73355.21  ...  141790.12        167398.89  2014
# ...

# %%
df['JobTitle'].str.contains('Captain',case=False).sum()
# Out:
# 552

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df['JobTitle'].str.contains('fire',case=False).sum()
# Out:
# 5879

# %% [markdown]
# #### job title contains fire case sensitive

# %%
df[df['JobTitle'].str.contains('fire',case=False)]
# Out:
#               EmployeeName                                          JobTitle  ... TotalPayBenefits  Year
# 4          PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  ...        326373.19  2011
# 6                ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)  ...        315981.05  2011
# 8           MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)  ...        303427.55  2011
# 9       JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  ...        302377.73  2011
# 10           ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  ...        299494.17  2011
# ...                    ...                                               ...  ...              ...   ...
# 145956    Kenneth C Farris                                       Firefighter  ...          4645.56  2014
# 147556       Edward A Dunn                                       Firefighter  ...          1581.80  2014
# ...

# %%
df[df['JobTitle'].str.contains('fire',case=False)]['EmployeeName']
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year',
#        'Fire_department_Ename', 'Department'],
#       dtype='object')

# %%
# df['BasePay']=df['BasePay'].astype(float)
df['BasePay']=df['BasePay'].str.replace('Not Provided','0')
df['BasePay']=df['BasePay'].astype(float)

# %%
df['BasePay'].describe()
# Out:
# count    17582.000000
# mean     29219.866678
# std      22187.012035
# min          0.000000
# 25%       7797.152500
# 50%      25336.765000
# 75%      51515.000000
# max      92945.870000
# Name: BasePay, dtype: float64

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year',
#        'Fire_department_Ename', 'Department'],
#       dtype='object')

# %%
import numpy as np
df['EmployeeName']=df['EmployeeName'].replace('Not provided',np.nan)

# %%
df.replace('Not provided', np.nan, inplace=True)

# %%
df
# Out:
#              EmployeeName  ...                                        Department
# 0          NATHANIEL FORD  ...  [GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY]
# 1            GARY JIMENEZ  ...                [CAPTAIN III , POLICE DEPARTMENT)]
# 2          ALBERT PARDINI  ...                [CAPTAIN III , POLICE DEPARTMENT)]
# 3       CHRISTOPHER CHONG  ...            [WIRE ROPE CABLE MAINTENANCE MECHANIC]
# 4         PATRICK GARDNER  ...   [DEPUTY CHIEF OF DEPARTMENT,, FIRE DEPARTMENT)]
# ...                   ...  ...                                               ...
# 148649      Roy I Tillery  ...                                       [Custodian]
# 148650                NaN  ...                                    [Not provided]
# 148651                NaN  ...                                    [Not provided]
# 148652                NaN  ...                                    [Not provided]
# 148653          Joe Lopez  ...                      [Counselor, Log Cabin Ranch]
#
# ...

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year',
#        'Fire_department_Ename', 'Department'],
#       dtype='object')

# %%
df.drop(['Fire_department_Ename'], axis=1)
# Out:
#              EmployeeName  ...                                        Department
# 0          NATHANIEL FORD  ...  [GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY]
# 1            GARY JIMENEZ  ...                [CAPTAIN III , POLICE DEPARTMENT)]
# 2          ALBERT PARDINI  ...                [CAPTAIN III , POLICE DEPARTMENT)]
# 3       CHRISTOPHER CHONG  ...            [WIRE ROPE CABLE MAINTENANCE MECHANIC]
# 4         PATRICK GARDNER  ...   [DEPUTY CHIEF OF DEPARTMENT,, FIRE DEPARTMENT)]
# ...                   ...  ...                                               ...
# 148649      Roy I Tillery  ...                                       [Custodian]
# 148650                NaN  ...                                    [Not provided]
# 148651                NaN  ...                                    [Not provided]
# 148652                NaN  ...                                    [Not provided]
# 148653          Joe Lopez  ...                      [Counselor, Log Cabin Ranch]
#
# ...

# %%
df[df.isnull().sum(axis=1)==5]
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Fire_department_Ename, Department]
# Index: []

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year',
#        'Fire_department_Ename', 'Department'],
#       dtype='object')

# %% [markdown]
# #### find employeee "Albert Pardini" and his tjob title

# %%
df[df['EmployeeName']=='Albert Pardini']['JobTitle']
# Out:
# 36519    Captain 3
# Name: JobTitle, dtype: object

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year',
#        'Fire_department_Ename', 'Department'],
#       dtype='object')

# %%
df[df['EmployeeName']=='Albert Pardini']['TotalPayBenefits']
# Out:
# 36519    253995.29
# Name: TotalPayBenefits, dtype: float64

# %%
df[df['BasePay'].max()==df['BasePay']]['EmployeeName']
# Out:
# 131453    Timothy J Lee
# Name: EmployeeName, dtype: object

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year',
#        'Fire_department_Ename', 'Department'],
#       dtype='object')

# %%
df['EmployeeName'].nunique()
# Out:
# 110810

# %%
r=df.groupby('Year')

for i in  r:
    print(i)
# Out:
# (2011,              EmployeeName  ...                                        Department
# 0          NATHANIEL FORD  ...  [GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY]
# 1            GARY JIMENEZ  ...                [CAPTAIN III , POLICE DEPARTMENT)]
# 2          ALBERT PARDINI  ...                [CAPTAIN III , POLICE DEPARTMENT)]
# 3       CHRISTOPHER CHONG  ...            [WIRE ROPE CABLE MAINTENANCE MECHANIC]
# 4         PATRICK GARDNER  ...   [DEPUTY CHIEF OF DEPARTMENT,, FIRE DEPARTMENT)]
# ...                   ...  ...                                               ...
# 36154       SERENA HUGHES  ...              [SWIMMING INSTRUCTOR/POOL LIFEGUARD]
# 36155        JOE BROWN JR  ...                                [TRANSIT OPERATOR]
# 36156      PAULETTE ADAMS  ...      [STATIONARY ENGINEER, WATER TREATMENT PLANT]
# 36157       KAUKAB MOHSIN  ...                                [TRANSIT OPERATOR]
# ...

# %%
df.groupby('Year').get_group(2011)
# Out:
#              EmployeeName  ...                                        Department
# 0          NATHANIEL FORD  ...  [GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY]
# 1            GARY JIMENEZ  ...                [CAPTAIN III , POLICE DEPARTMENT)]
# 2          ALBERT PARDINI  ...                [CAPTAIN III , POLICE DEPARTMENT)]
# 3       CHRISTOPHER CHONG  ...            [WIRE ROPE CABLE MAINTENANCE MECHANIC]
# 4         PATRICK GARDNER  ...   [DEPUTY CHIEF OF DEPARTMENT,, FIRE DEPARTMENT)]
# ...                   ...  ...                                               ...
# 36154       SERENA HUGHES  ...              [SWIMMING INSTRUCTOR/POOL LIFEGUARD]
# 36155        JOE BROWN JR  ...                                [TRANSIT OPERATOR]
# 36156      PAULETTE ADAMS  ...      [STATIONARY ENGINEER, WATER TREATMENT PLANT]
# 36157       KAUKAB MOHSIN  ...                                [TRANSIT OPERATOR]
# 36158  JOSEPHINE MCCREARY  ...                                      [MANAGER IV]
#
# ...

# %% [markdown]
# #### find mean of bsepay of all employees per year

# %%
grpfunc=df.groupby('Year')
grpfunc['BasePay'].aggregate(np.mean)
# Out:
# Year
# 2011             NaN
# 2012             NaN
# 2013             NaN
# 2014    29219.866678
# Name: BasePay, dtype: float64

# %%
df['BasePay'].dtype
# Out:
# dtype('float64')

# %%
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011             NaN
# 2012             NaN
# 2013             NaN
# 2014    29219.866678
# Name: BasePay, dtype: float64

# %%
grp=df.groupby('JobTitle')

grp['BasePay'].aggregate(np.mean)
# Out:
# JobTitle
# ACCOUNT CLERK                                              NaN
# ACCOUNTANT                                                 NaN
# ACCOUNTANT INTERN                                          NaN
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                              NaN
#                                                       ...
# X-RAY LABORATORY AIDE                                      NaN
# X-Ray Laboratory Aide                             34056.416818
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS             NaN
# Youth Comm Advisor                                32417.420000
# ZOO CURATOR                                                NaN
# Name: BasePay, Length: 2158, dtype: float64

# %%
grp=df.groupby('JobTitle').get_group('ACCOUNTANT')

grp['BasePay'].aggregate(np.mean)
# Out:
# nan

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year',
#        'Fire_department_Ename', 'Department'],
#       dtype='object')

# %% [markdown]
# #### unique values in jobtitle display top 5

# %%
df['JobTitle'].value_counts().head(n=5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
grp=df.groupby('JobTitle')
for i, y in grp:
    print(i)
    print(y.shape)
# Out:
# ACCOUNT CLERK
# (83, 11)
# ACCOUNTANT
# (5, 11)
# ACCOUNTANT INTERN
# (48, 11)
# ACPO,JuvP, Juv Prob (SFERS)
# (1, 11)
# ACUPUNCTURIST
# (1, 11)
# ADMINISTRATIVE ANALYST
# (93, 11)
# ADMINISTRATIVE ANALYST II
# (2, 11)
# ADMINISTRATIVE ANALYST III
# (2, 11)
# ADMINISTRATIVE ENGINEER
# (10, 11)
# ADMINISTRATIVE SERVICES MANAGER
# (3, 11)
# ADMINISTRATOR, SFGH MEDICAL CENTER
# (1, 11)
# AFFIRMATIVE ACTION SPECIALIST
# (6, 11)
# AGRICULTURAL INSPECTOR
# (2, 11)
# AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI
# (1, 11)
# AIRPORT ASSISTANT DEPUTY DIRECTOR, OPERATIONS
# (1, 11)
# AIRPORT COMMUNICATIONS OPERATOR
# (27, 11)
# AIRPORT COMMUNICATIONS SUPERVISOR
# (2, 11)
# AIRPORT ECONOMIC PLANNER
# (13, 11)
# AIRPORT ELECTRICIAN
# (17, 11)
# AIRPORT ELECTRICIAN SUPERVISOR
# (2, 11)
# AIRPORT EMERGENCY PLANNING COORDINATOR
# (2, 11)
# AIRPORT MECHANICAL MAINTENANCE SUPERVISOR
# (1, 11)
# AIRPORT NOISE ABATEMENT SPECIALIST
# (2, 11)
# AIRPORT OPERATIONS SUPERVISOR
# (12, 11)
# ...

# %%
df.isin([335279.91])
# Out:
#         EmployeeName  JobTitle  BasePay  OvertimePay  ...  TotalPayBenefits   Year  Fire_department_Ename  Department
# 0              False     False    False        False  ...             False  False                  False       False
# 1              False     False    False        False  ...             False  False                  False       False
# 2              False     False    False        False  ...              True  False                  False       False
# 3              False     False    False        False  ...             False  False                  False       False
# 4              False     False    False        False  ...             False  False                  False       False
# ...              ...       ...      ...          ...  ...               ...    ...                    ...         ...
# 148649         False     False    False        False  ...             False  False                  False       False
# ...

# %%
r=(df==5).any().any()

# %%
r
# Out:
# True

# %% [markdown]
# #### search for unique value in full data frame and display matching rows

# %%
df[df.eq('DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)').any(axis=1)]
# Out:
#        EmployeeName  ...                                       Department
# 4   PATRICK GARDNER  ...  [DEPUTY CHIEF OF DEPARTMENT,, FIRE DEPARTMENT)]
# 29    MONICA FIELDS  ...  [DEPUTY CHIEF OF DEPARTMENT,, FIRE DEPARTMENT)]
# 42  THOMAS SIRAGUSA  ...  [DEPUTY CHIEF OF DEPARTMENT,, FIRE DEPARTMENT)]
#
# [3 rows x 11 columns]
